# %%
#Start Application with Flask as the Web Framework of Choice
from flask import Flask, jsonify, request, render_template
from flask_cors import CORS

app = Flask(__name__)

# Add CORS to the API
CORS(app)

# %%
#2 Start Data Processing by obtaining excel file given as part of PWS
#Utilizing Padas
import pandas as pd
#Utilizing NumPy
import numpy as np
# Importing JSON for API 
import json

df = pd.DataFrame()
cols_to_use = [0,1,2,3,4,5,6,7]
csv_file_path = "../../assets/companylist.csv"
df = pd.read_csv(csv_file_path, 
    usecols= cols_to_use,
    encoding='utf-8'
    )
#IPOYear - initial public offering
#MarketCap - total value of all a company's shares of stock
#Sort Companies by Sector
df.sort_values(by=['Sector'], ascending=False).head()

#Identify how may unique sectors are actually in the data given
list_of_unique_sectors = df['Sector'].unique().tolist()
print(list_of_unique_sectors)
# Count the number of Unique Sectors
count_of_unique_sectors = len(df['Sector'].unique().tolist())
print(count_of_unique_sectors)
# Reviewed the List of Sectors to notice NaN for missing data. 
# Creating a new column for sector that will be clean as well as consolidating sectors to 10
# Migrating all Consumer Sectors to Consumer Industry and Technology with Energy.
df['Sector_Conv'] = np.where(df['Sector']=="Consumer Durables", 'Consumer Industry', df['Sector'])
df['Sector_Conv'] = np.where(df['Sector']=="Consumer Non-Durables", 'Consumer Industry', df['Sector'])
df['Sector_Conv'] = np.where(df['Sector']=='Consumer Services', 'Consumer Industry', df['Sector'])
df["Sector"] = df["Sector"].replace("Empty", "No Industry Identified")
df["Sector_Conv"] = df["Sector_Conv"].replace("Empty", "No Industry Identified")
df["Sector_Conv"] = df["Sector_Conv"].replace("Consumer Durables", "Consumer Industry")
df["Sector_Conv"] = df["Sector_Conv"].replace("Consumer Non-Durables", "Consumer Industry")
df["Sector_Conv"] = df["Sector_Conv"].replace("Technology", "Technology/Energy")
df["Sector_Conv"] = df["Sector_Conv"].replace("Energy", "Technology/Energy")

# Checking the conversion and consolidation
list_of_unique_sectors_conversion = df['Sector_Conv'].unique().tolist()
# print(list_of_unique_sectors_conversion)
# Checking the correct number of unique sectors
count_of_unique_sectors = len(df['Sector_Conv'].unique().tolist())
# print(count_of_unique_sectors)

# Remove NaN from to Sector Identified
df['Sector_Conv'] = df['Sector_Conv'].fillna('No Sector Identifed')

# Checking the conversion and consolidation - Count should be the same.
list_of_unique_sectors_conversion = df['Sector_Conv'].unique().tolist()
print(list_of_unique_sectors_conversion)

# Convert list to a JSON Object
json_sector_list = json.dumps(list_of_unique_sectors_conversion)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-c3107faf7d68> in <module>
#       1 #2 Start Data Processing by obtaining excel file given as part of PWS
#       2 #Utilizing Padas
# ----> 3 import pandas as pd
#       4 #Utilizing NumPy
#       5 import numpy as np
#
# ModuleNotFoundError: No module named 'pandas'

# %%
list_of_symbols = df['Symbol'].unique().tolist()
# list_of_symbols[:10]
# Out:
# ['YI', 'PIH', 'PIHPP', 'TURN', 'FLWS', 'BCOW', 'FCCY', 'SRCE', 'VNET', 'TWOU']

# %%
# Obtaining historical records from API for a company by utilizing their symbols on the previous workbook.
import requests
def get_stock_data_from_alphavantage_by_symbol(symbols):
    Alpha_Advantage_API = "https://www.alphavantage.co/query?function=TIME_SERIES_DAILY&symbol=AMZN&outputsize=full&apikey=GJS1X1O8CLA8KA4H"
    resp = requests.get(Alpha_Advantage_API)
    if resp.status_code == 200:
#         print(resp.status_code)
        data = resp.json()
        data = data['Time Series (Daily)']
#         print(data)
        df = pd.DataFrame.from_dict(data, orient='columns')
        df = df.T
        return df.head()
    else:
        print("API did not pull any data from alphavantage")
# Executes the function
get_stock_data_from_alphavantage_by_symbol(list_of_symbols)
# Out:
#               1. open    2. high     3. low   4. close 5. volume
# 2019-05-30  1825.4900  1826.0000  1816.9900  1819.6500    263732
# 2019-05-29  1823.1200  1830.0000  1807.5300  1819.1900   4272379
# 2019-05-28  1832.7500  1849.2700  1827.3500  1836.4300   3199965
# 2019-05-24  1835.8900  1841.7600  1817.8500  1823.2800   3369673
# 2019-05-23  1836.5900  1844.0000  1804.2000  1815.4800   4424265

# %%
df['industry'] = df['industry'].fillna('No Industry Identified')
df['industry'].unique().tolist()
# len(df['industry'].unique().tolist())
# Out:
# ['Medical/Nursing Services',
#  'Property-Casualty Insurers',
#  'Finance/Investors Services',
#  'Other Specialty Stores',
#  'Banks',
#  'Savings Institutions',
#  'Major Banks',
#  'Computer Software: Programming, Data Processing',
#  'Computer Software: Prepackaged Software',
#  'Finance: Consumer Services',
#  'Diversified Commercial Services',
#  'Business Services',
#  'EDP Services',
#  'Industrial Machinery/Components',
#  'Major Pharmaceuticals',
#  'Telecommunications Equipment',
#  'Medical/Dental Instruments',
#  'Oil & Gas Production',
#  'Semiconductors',
#  'Multi-Sector Companies',
#  'Medical Specialities',
#  'Biotechnology: Laboratory Analytical Instruments',
#  'No Industry Identified',
#  'Biotechnology: Biological Products (No Diagnostic Substances)',
#  'Biotechnology: In Vitro & In Vivo Diagnostic Substances',
#  'Office Equipment/Supplies/Services',
#  'Auto Parts:O.E.M.',
#  'Major Chemicals',
#  'Water Supply',
#  'Electrical Products',
#  'Aerospace',
#  'Real Estate Investment Trusts',
#  'Air Freight/Delivery Services',
#  'Radio And Television Broadcasting And Communications Equipment']

# %%
df.groupby(['Name','Sector','industry']).groups
# Out:
# {('111, Inc.',
#   'Health Care',
#   'Medical/Nursing Services'): Int64Index([0], dtype='int64'),
#  ('1347 Property Insurance Holdings, Inc.',
#   'Finance',
#   'Property-Casualty Insurers'): Int64Index([1, 2], dtype='int64'),
#  ('180 Degree Capital Corp.',
#   'Finance',
#   'Finance/Investors Services'): Int64Index([3], dtype='int64'),
#  ('1-800 FLOWERS.COM, Inc.',
#   'Consumer Services',
#   'Other Specialty Stores'): Int64Index([4], dtype='int64'),
#  ('1895 Bancorp of Wisconsin, Inc.',
#   'Finance',
#   'Banks'): Int64Index([5], dtype='int64'),
#  ('1st Constitution Bancorp (NJ)',
#   'Finance',
#   'Savings Institutions'): Int64Index([6], dtype='int64'),
#  ('1st Source Corporation',
#   'Finance',
#   'Major Banks'): Int64Index([7], dtype='int64'),
#  ('21Vianet Group, Inc.',
#   'Technology',
#   'Computer Software: Programming, Data Processing'): Int64Index([8], dtype='int64'),
#  ('2U, Inc.',
#   'Technology',
#   'Computer Software: Prepackaged Software'): Int64Index([9], dtype='int64'),
#  ('360 Finance, Inc.',
#   'Finance',
#   'Finance: Consumer Services'): Int64Index([10], dtype='int64'),
#  ('51job, Inc.',
#   'Technology',
#   'Diversified Commercial Services'): Int64Index([11], dtype='int64'),
#  ('8i Enterprises Acquisition Corp',
#   'Finance',
#   'Business Services'): Int64Index([12, 13, 14, 15], dtype='int64'),
#  ('8x8 Inc', 'Technology', 'EDP Services'): Int64Index([16], dtype='int64'),
#  ('AAON, Inc.',
#   'Capital Goods',
#   'Industrial Machinery/Components'): Int64Index([17], dtype='int64'),
#  ('Abeona Therapeutics Inc.',
#   'Health Care',
#   'Major Pharmaceuticals'): Int64Index([18, 19], dtype='int64'),
#  ('Ability Inc.',
#   'Capital Goods',
#   'Telecommunications Equipment'): Int64Index([20], dtype='int64'),
#  ('ABIOMED, Inc.',
#   'Health Care',
#   'Medical/Dental Instruments'): Int64Index([21], dtype='int64'),
#  ('Abraxas Petroleum Corporation',
#   'Energy',
#   'Oil & Gas Production'): Int64Index([22], dtype='int64'),
#  ('AC Immune SA',
#   'Health Care',
#   'Major Pharmaceuticals'): Int64Index([23], dtype='int64'),
#  ('Acacia Communications, Inc.',
#   'Technology',
#   'Semiconductors'): Int64Index([24], dtype='int64'),
#  ('Acacia Research Corporation',
#   'Miscellaneous',
#   'Multi-Sector Companies'): Int64Index([25], dtype='int64'),
#  ('Acadia Healthcare Company, Inc.',
#   'Health Care',
#   'Medical Specialities'): Int64Index([26], dtype='int64'),
#  ('ACADIA Pharmaceuticals Inc.',
#   'Health Care',
#   'Major Pharmaceuticals'): Int64Index([27], dtype='int64'),
#  ('Acamar Partners Acquisition Corp.',
#   'Finance',
#   'Business Services'): Int64Index([28, 29, 30], dtype='int64'),
#  ('Acasti Pharma, Inc.',
#   'Health Care',
#   'Major Pharmaceuticals'): Int64Index([31], dtype='int64'),
#  ('Accelerate Diagnostics, Inc.',
#   'Capital Goods',
#   'Biotechnology: Laboratory Analytical Instruments'): Int64Index([32], dtype='int64'),
#  ('Accelerated Pharma, Inc.',
#   nan,
#   'No Industry Identified'): Int64Index([33], dtype='int64'),
#  ('Acceleron Pharma Inc.',
#   'Health Care',
#   'Biotechnology: Biological Products (No Diagnostic Substances)'): Int64Index([34], dtype='int64'),
#  ('Accuray Incorporated',
#   'Health Care',
#   'Medical/Dental Instruments'): Int64Index([35], dtype='int64'),
#  ('AcelRx Pharmaceuticals, Inc.',
#   'Health Care',
#   'Major Pharmaceuticals'): Int64Index([36], dtype='int64'),
#  ('Acer Therapeutics Inc.',
#   'Health Care',
#   'Major Pharmaceuticals'): Int64Index([37], dtype='int64'),
#  ('Achieve Life Sciences, Inc. ',
#   'Health Care',
#   'Biotechnology: In Vitro & In Vivo Diagnostic Substances'): Int64Index([38], dtype='int64'),
#  ('Achillion Pharmaceuticals, Inc.',
#   'Health Care',
#   'Major Pharmaceuticals'): Int64Index([39], dtype='int64'),
#  ('ACI Worldwide, Inc.',
#   'Technology',
#   'Computer Software: Prepackaged Software'): Int64Index([40], dtype='int64'),
#  ('Aclaris Therapeutics, Inc.',
#   'Health Care',
#   'Major Pharmaceuticals'): Int64Index([41], dtype='int64'),
#  ('ACM Research, Inc.',
#   'Technology',
#   'Industrial Machinery/Components'): Int64Index([42], dtype='int64'),
#  ('ACNB Corporation',
#   'Finance',
#   'Major Banks'): Int64Index([43], dtype='int64'),
#  ('Acorda Therapeutics, Inc.',
#   'Health Care',
#   'Biotechnology: Biological Products (No Diagnostic Substances)'): Int64Index([44], dtype='int64'),
#  ('Act II Global Acquisition Corp.',
#   'Finance',
#   'Business Services'): Int64Index([45, 46, 47], dtype='int64'),
#  ('Activision Blizzard, Inc',
#   'Technology',
#   'Computer Software: Prepackaged Software'): Int64Index([48], dtype='int64'),
#  ('Adamas Pharmaceuticals, Inc.',
#   'Health Care',
#   'Major Pharmaceuticals'): Int64Index([49], dtype='int64'),
#  ('Adamis Pharmaceuticals Corporation',
#   'Health Care',
#   'Major Pharmaceuticals'): Int64Index([50], dtype='int64'),
#  ('Adaptimmune Therapeutics plc',
#   'Health Care',
#   'Biotechnology: Biological Products (No Diagnostic Substances)'): Int64Index([51], dtype='int64'),
#  ('Addus HomeCare Corporation',
#   'Health Care',
#   'Medical/Nursing Services'): Int64Index([52], dtype='int64'),
#  ('ADDvantage Technologies Group, Inc.',
#   'Consumer Services',
#   'Office Equipment/Supplies/Services'): Int64Index([53], dtype='int64'),
#  ('Adesto Technologies Corporation',
#   'Technology',
#   'Semiconductors'): Int64Index([54], dtype='int64'),
#  ('Adial Pharmaceuticals, Inc',
#   'Health Care',
#   'Major Pharmaceuticals'): Int64Index([55, 56], dtype='int64'),
#  ('ADMA Biologics Inc',
#   'Health Care',
#   'Biotechnology: Biological Products (No Diagnostic Substances)'): Int64Index([57], dtype='int64'),
#  ('Adobe Inc.',
#   'Technology',
#   'Computer Software: Prepackaged Software'): Int64Index([58], dtype='int64'),
#  ('ADOMANI, Inc.',
#   'Capital Goods',
#   'Auto Parts:O.E.M.'): Int64Index([59], dtype='int64'),
#  ('ADTRAN, Inc.',
#   'Public Utilities',
#   'Telecommunications Equipment'): Int64Index([60], dtype='int64'),
#  ('Aduro Biotech, Inc.',
#   'Health Care',
#   'Major Pharmaceuticals'): Int64Index([61], dtype='int64'),
#  ('Advanced Emissions Solutions, Inc.',
#   'Basic Industries',
#   'Major Chemicals'): Int64Index([62], dtype='int64'),
#  ('Advanced Energy Industries, Inc.',
#   'Capital Goods',
#   'Industrial Machinery/Components'): Int64Index([63], dtype='int64'),
#  ('Advanced Micro Devices, Inc.',
#   'Technology',
#   'Semiconductors'): Int64Index([64], dtype='int64'),
#  ('Advaxis, Inc.',
#   'Health Care',
#   'Major Pharmaceuticals'): Int64Index([65], dtype='int64'),
#  ('Adverum Biotechnologies, Inc.',
#   'Health Care',
#   'Biotechnology: Biological Products (No Diagnostic Substances)'): Int64Index([66], dtype='int64'),
#  ('AdvisorShares Dorsey Wright Micro-Cap ETF',
#   nan,
#   'No Industry Identified'): Int64Index([67], dtype='int64'),
#  ('AdvisorShares Dorsey Wright Short ETF',
#   nan,
#   'No Industry Identified'): Int64Index([68], dtype='int64'),
#  ('AdvisorShares Sabretooth ETF',
#   nan,
#   'No Industry Identified'): Int64Index([69], dtype='int64'),
#  ('AdvisorShares Vice ETF',
#   nan,
#   'No Industry Identified'): Int64Index([70], dtype='int64'),
#  ('Adynxx, Inc.',
#   'Health Care',
#   'Medical/Dental Instruments'): Int64Index([71], dtype='int64'),
#  ('Aegion Corp',
#   'Basic Industries',
#   'Water Supply'): Int64Index([72], dtype='int64'),
#  ('Aeglea BioTherapeutics, Inc.',
#   'Health Care',
#   'Major Pharmaceuticals'): Int64Index([73], dtype='int64'),
#  ('Aehr Test Systems',
#   'Capital Goods',
#   'Electrical Products'): Int64Index([74], dtype='int64'),
#  ('Aemetis, Inc',
#   'Basic Industries',
#   'Major Chemicals'): Int64Index([75], dtype='int64'),
#  ('Aerie Pharmaceuticals, Inc.',
#   'Health Care',
#   'Biotechnology: Biological Products (No Diagnostic Substances)'): Int64Index([76], dtype='int64'),
#  ('AeroVironment, Inc.',
#   'Capital Goods',
#   'Aerospace'): Int64Index([77], dtype='int64'),
#  ('Aerpio Pharmaceuticals, Inc.',
#   'Health Care',
#   'Major Pharmaceuticals'): Int64Index([78], dtype='int64'),
#  ('AEterna Zentaris Inc.',
#   'Health Care',
#   'Major Pharmaceuticals'): Int64Index([79], dtype='int64'),
#  ('Aethlon Medical, Inc.',
#   'Capital Goods',
#   'Biotechnology: Laboratory Analytical Instruments'): Int64Index([80], dtype='int64'),
#  ('Aevi Genomic Medicine, Inc.',
#   'Health Care',
#   'Biotechnology: Biological Products (No Diagnostic Substances)'): Int64Index([81], dtype='int64'),
#  ('Affimed N.V.',
#   'Health Care',
#   'Major Pharmaceuticals'): Int64Index([82], dtype='int64'),
#  ('AGBA Acquisition Limited',
#   'Finance',
#   'Business Services'): Int64Index([83], dtype='int64'),
#  ('Agenus Inc.',
#   'Health Care',
#   'Biotechnology: Biological Products (No Diagnostic Substances)'): Int64Index([84], dtype='int64'),
#  ('Agile Therapeutics, Inc.',
#   'Health Care',
#   'Major Pharmaceuticals'): Int64Index([85], dtype='int64'),
#  ('Agilysys, Inc.',
#   'Technology',
#   'EDP Services'): Int64Index([86], dtype='int64'),
#  ('Agios Pharmaceuticals, Inc.',
#   'Health Care',
#   'Major Pharmaceuticals'): Int64Index([87], dtype='int64'),
#  ('AGM Group Holdings Inc.',
#   'Technology',
#   'EDP Services'): Int64Index([88], dtype='int64'),
#  ('AGNC Investment Corp.',
#   'Consumer Services',
#   'Real Estate Investment Trusts'): Int64Index([89, 90, 91, 92], dtype='int64'),
#  ('AgroFresh Solutions, Inc.',
#   'Finance',
#   'Business Services'): Int64Index([93, 94], dtype='int64'),
#  ('Aileron Therapeutics, Inc.',
#   'Health Care',
#   'Major Pharmaceuticals'): Int64Index([95], dtype='int64'),
#  ('Aimmune Therapeutics, Inc.',
#   'Health Care',
#   'Major Pharmaceuticals'): Int64Index([96], dtype='int64'),
#  ('Air T, Inc.',
#   'Transportation',
#   'Air Freight/Delivery Services'): Int64Index([97], dtype='int64'),
#  ('Air Transport Services Group, Inc',
#   'Transportation',
#   'Air Freight/Delivery Services'): Int64Index([98], dtype='int64'),
#  ('Airgain, Inc.',
#   'Technology',
#   'Radio And Television Broadcasting And Communications Equipment'): Int64Index([99], dtype='int64'),
#  ('AirMedia Group Inc.',
#   'Technology',
#   'No Industry Identified'): Int64Index([100], dtype='int64'),
#  ('AIT Therapeutics, Inc.',
#   'Health Care',
#   'No Industry Identified'): Int64Index([101], dtype='int64'),
#  ('Akamai Technologies, Inc.',
#   'Miscellaneous',
#   'No Industry Identified'): Int64Index([102], dtype='int64'),
#  ('Akari Therapeutics Plc',
#   'Health Care',
#   'No Industry Identified'): Int64Index([103], dtype='int64'),
#  ('Akcea Therapeutics, Inc.',
#   'Health Care',
#   'No Industry Identified'): Int64Index([104], dtype='int64'),
#  ('Akebia Therapeutics, Inc.',
#   'Health Care',
#   'No Industry Identified'): Int64Index([105], dtype='int64'),
#  ('Akers Biosciences Inc.',
#   'Health Care',
#   'No Industry Identified'): Int64Index([106], dtype='int64'),
#  ('Akorn, Inc.',
#   'Health Care',
#   'No Industry Identified'): Int64Index([107], dtype='int64'),
#  ('Akoustis Technologies, Inc.',
#   'Public Utilities',
#   'No Industry Identified'): Int64Index([108], dtype='int64'),
#  ('Alarm.com Holdings, Inc.',
#   'Technology',
#   'No Industry Identified'): Int64Index([109], dtype='int64'),
#  ('Alaska Communications Systems Group, Inc.',
#   'Public Utilities',
#   'No Industry Identified'): Int64Index([110], dtype='int64'),
#  ('Alberton Acquisition Corporation',
#   'Finance',
#   'No Industry Identified'): Int64Index([111, 112, 113, 114], dtype='int64'),
#  ('Albireo Pharma, Inc.',
#   'Health Care',
#   'No Industry Identified'): Int64Index([115], dtype='int64'),
#  ('Alcentra Capital Corp.',
#   nan,
#   'No Industry Identified'): Int64Index([116], dtype='int64'),
#  ('Alder BioPharmaceuticals, Inc.',
#   'Health Care',
#   'No Industry Identified'): Int64Index([117], dtype='int64'),
#  ('Aldeyra Therapeutics, Inc.',
#   'Health Care',
#   'No Industry Identified'): Int64Index([118], dtype='int64'),
#  ('Alector, Inc.',
#   'Health Care',
#   'No Industry Identified'): Int64Index([119], dtype='int64'),
#  ('Alexion Pharmaceuticals, Inc.',
#   'Health Care',
#   'No Industry Identified'): Int64Index([120], dtype='int64'),
#  ('Alico, Inc.',
#   'Consumer Non-Durables',
#   'No Industry Identified'): Int64Index([121], dtype='int64'),
#  ('Alight Inc.',
#   nan,
#   'No Industry Identified'): Int64Index([122], dtype='int64'),
#  ('Align Technology, Inc.',
#   'Health Care',
#   'No Industry Identified'): Int64Index([123], dtype='int64'),
#  ('Alimera Sciences, Inc.',
#   'Health Care',
#   'No Industry Identified'): Int64Index([124], dtype='int64'),
#  ('Alithya Group inc.',
#   'Technology',
#   'No Industry Identified'): Int64Index([125], dtype='int64'),
#  ('ALJ Regional Holdings, Inc.',
#   'Miscellaneous',
#   'No Industry Identified'): Int64Index([126], dtype='int64'),
#  ('Alkermes plc',
#   'Health Care',
#   'No Industry Identified'): Int64Index([127], dtype='int64'),
#  ('Allakos Inc.',
#   'Health Care',
#   'No Industry Identified'): Int64Index([128], dtype='int64'),
#  ('Allegiance Bancshares, Inc.',
#   'Finance',
#   'No Industry Identified'): Int64Index([129], dtype='int64'),
#  ('Allegiant Travel Company',
#   'Transportation',
#   'No Industry Identified'): Int64Index([130], dtype='int64'),
#  ('Allegro Merger Corp.',
#   'Finance',
#   'No Industry Identified'): Int64Index([131, 132, 133, 134], dtype='int64'),
#  ('Allena Pharmaceuticals, Inc.',
#   'Health Care',
#   'No Industry Identified'): Int64Index([135], dtype='int64'),
#  ('Alliance Resource Partners, L.P.',
#   'Energy',
#   'No Industry Identified'): Int64Index([136], dtype='int64'),
#  ('Alliant Energy Corporation',
#   'Public Utilities',
#   'No Industry Identified'): Int64Index([137], dtype='int64'),
#  ('Allied Healthcare Products, Inc.',
#   'Health Care',
#   'No Industry Identified'): Int64Index([138], dtype='int64'),
#  ('Allied Motion Technologies, Inc.',
#   'Capital Goods',
#   'No Industry Identified'): Int64Index([139], dtype='int64'),
#  ('Allogene Therapeutics, Inc.',
#   'Health Care',
#   'No Industry Identified'): Int64Index([140], dtype='int64'),
#  ('Allot Ltd.',
#   'Technology',
#   'No Industry Identified'): Int64Index([141], dtype='int64'),
#  ('Allscripts Healthcare Solutions, Inc.',
#   'Technology',
#   'No Industry Identified'): Int64Index([142], dtype='int64'),
#  ('Alnylam Pharmaceuticals, Inc.',
#   'Health Care',
#   'No Industry Identified'): Int64Index([143], dtype='int64'),
#  ('Alpha and Omega Semiconductor Limited',
#   'Technology',
#   'No Industry Identified'): Int64Index([144], dtype='int64'),
#  ('Alphabet Inc.',
#   'Technology',
#   'No Industry Identified'): Int64Index([145, 146], dtype='int64'),
#  ('AlphaMark Actively Managed Small Cap ETF',
#   nan,
#   'No Industry Identified'): Int64Index([147], dtype='int64'),
#  ('Alphatec Holdings, Inc.',
#   'Health Care',
#   'No Industry Identified'): Int64Index([148], dtype='int64'),
#  ('Alpine Immune Sciences, Inc.',
#   'Health Care',
#   'No Industry Identified'): Int64Index([149], dtype='int64'),
#  ('Alta Mesa Resources, Inc.',
#   'Energy',
#   'No Industry Identified'): Int64Index([150, 151], dtype='int64'),
#  ('Altaba Inc.',
#   'Technology',
#   'No Industry Identified'): Int64Index([152], dtype='int64'),
#  ('Altair Engineering Inc.',
#   'Technology',
#   'No Industry Identified'): Int64Index([153], dtype='int64'),
#  ('Alterity Therapeutics Limited',
#   'Health Care',
#   'No Industry Identified'): Int64Index([154], dtype='int64'),
#  ('Altimmune, Inc.',
#   'Health Care',
#   'No Industry Identified'): Int64Index([155], dtype='int64'),
#  ('Altisource Portfolio Solutions S.A.',
#   'Consumer Services',
#   'No Industry Identified'): Int64Index([156], dtype='int64'),
#  ('Altra Industrial Motion Corp.',
#   'Capital Goods',
#   'No Industry Identified'): Int64Index([157], dtype='int64'),
#  ('Altus Midstream Company',
#   'Public Utilities',
#   'No Industry Identified'): Int64Index([158], dtype='int64'),
#  ('AMAG Pharmaceuticals, Inc.',
#   'Health Care',
#   'No Industry Identified'): Int64Index([159], dtype='int64'),
#  ('Amalgamated Bank',
#   'Consumer Non-Durables',
#   'No Industry Identified'): Int64Index([160], dtype='int64'),
#  ('Amarin Corporation plc',
#   'Health Care',
#   'No Industry Identified'): Int64Index([161], dtype='int64'),
#  ('A-Mark Precious Metals, Inc.',
#   'Basic Industries',
#   'No Industry Identified'): Int64Index([162], dtype='int64'),
#  ('Amazon.com, Inc.',
#   'Consumer Services',
#   'No Industry Identified'): Int64Index([163], dtype='int64'),
#  ('Ambac Financial Group, Inc.',
#   'Finance',
#   'No Industry Identified'): Int64Index([164, 165], dtype='int64'),
#  ('Ambarella, Inc.',
#   'Technology',
#   'No Industry Identified'): Int64Index([166], dtype='int64'),
#  ('AMC Networks Inc.',
#   'Consumer Services',
#   'No Industry Identified'): Int64Index([167], dtype='int64'),
#  ('AMCI Acquisition Corp.',
#   'Finance',
#   'No Industry Identified'): Int64Index([168, 169, 170], dtype='int64'),
#  ('Amdocs Limited',
#   'Technology',
#   'No Industry Identified'): Int64Index([171], dtype='int64'),
#  ('Amedisys Inc',
#   'Health Care',
#   'No Industry Identified'): Int64Index([172], dtype='int64'),
#  ('Amerco',
#   'Consumer Services',
#   'No Industry Identified'): Int64Index([173], dtype='int64'),
#  ('Ameri Holdings, Inc.',
#   'Technology',
#   'No Industry Identified'): Int64Index([174, 175], dtype='int64'),
#  ('America First Multifamily Investors, L.P.',
#   'Finance',
#   'No Industry Identified'): Int64Index([176], dtype='int64'),
#  ('America Movil, S.A.B. de C.V.',
#   'Public Utilities',
#   'No Industry Identified'): Int64Index([177], dtype='int64'),
#  ('American Airlines Group, Inc.',
#   'Transportation',
#   'No Industry Identified'): Int64Index([178], dtype='int64'),
#  ('American Electric Technologies, Inc.',
#   'Energy',
#   'No Industry Identified'): Int64Index([179], dtype='int64'),
#  ('American Finance Trust, Inc.',
#   'Consumer Services',
#   'No Industry Identified'): Int64Index([180, 181], dtype='int64'),
#  ('American National Bankshares, Inc.',
#   'Finance',
#   'No Industry Identified'): Int64Index([182], dtype='int64'),
#  ('American National Insurance Company',
#   'Finance',
#   'No Industry Identified'): Int64Index([183], dtype='int64'),
#  ('American Outdoor Brands Corporation',
#   'Capital Goods',
#   'No Industry Identified'): Int64Index([184], dtype='int64'),
#  ('American Public Education, Inc.',
#   'Consumer Services',
#   'No Industry Identified'): Int64Index([185], dtype='int64'),
#  ('American Resources Corporation',
#   'Consumer Services',
#   'No Industry Identified'): Int64Index([186], dtype='int64'),
#  ('American River Bankshares',
#   'Finance',
#   'No Industry Identified'): Int64Index([187], dtype='int64'),
#  ('American Software, Inc.',
#   'Technology',
#   'No Industry Identified'): Int64Index([188], dtype='int64'),
#  ('American Superconductor Corporation',
#   'Consumer Durables',
#   'No Industry Identified'): Int64Index([189], dtype='int64'),
#  ('American Woodmark Corporation',
#   'Basic Industries',
#   'No Industry Identified'): Int64Index([190], dtype='int64'),
#  ('America&#39;s Car-Mart, Inc.',
#   'Consumer Durables',
#   'No Industry Identified'): Int64Index([191], dtype='int64'),
#  ('Ameris Bancorp',
#   'Finance',
#   'No Industry Identified'): Int64Index([192], dtype='int64'),
#  ('AMERISAFE, Inc.',
#   'Finance',
#   'No Industry Identified'): Int64Index([193], dtype='int64'),
#  ('AmeriServ Financial Inc.',
#   'Finance',
#   'No Industry Identified'): Int64Index([194, 195], dtype='int64'),
#  ('Ames National Corporation',
#   'Finance',
#   'No Industry Identified'): Int64Index([196], dtype='int64'),
#  ('Amgen Inc.',
#   'Health Care',
#   'No Industry Identified'): Int64Index([197], dtype='int64'),
#  ('Amicus Therapeutics, Inc.',
#   'Health Care',
#   'No Industry Identified'): Int64Index([198], dtype='int64'),
#  ('Amkor Technology, Inc.',
#   'Technology',
#   'No Industry Identified'): Int64Index([199], dtype='int64'),
#  ('Amphastar Pharmaceuticals, Inc.',
#   'Health Care',
#   'No Industry Identified'): Int64Index([200], dtype='int64'),
#  ('Amplify Online Retail ETF',
#   nan,
#   'No Industry Identified'): Int64Index([201], dtype='int64'),
#  ('Amtech Systems, Inc.',
#   'Technology',
#   'No Industry Identified'): Int64Index([202], dtype='int64'),
#  ('Amyris, Inc.',
#   'Basic Industries',
#   'No Industry Identified'): Int64Index([203], dtype='int64'),
#  ('Analog Devices, Inc.',
#   'Technology',
#   'No Industry Identified'): Int64Index([204], dtype='int64'),
#  ('AnaptysBio, Inc.',
#   'Health Care',
#   'No Industry Identified'): Int64Index([205], dtype='int64'),
#  ('Anavex Life Sciences Corp.',
#   'Health Care',
#   'No Industry Identified'): Int64Index([206], dtype='int64'),
#  ('Anchiano Therapeutics Ltd.',
#   'Health Care',
#   'No Industry Identified'): Int64Index([207], dtype='int64'),
#  ('Andina Acquisition Corp. III',
#   'Finance',
#   'No Industry Identified'): Int64Index([208, 209, 210, 211], dtype='int64'),
#  ('ANGI Homeservices Inc.',
#   'Consumer Services',
#   'No Industry Identified'): Int64Index([212], dtype='int64'),
#  ('AngioDynamics, Inc.',
#   'Health Care',
#   'No Industry Identified'): Int64Index([213], dtype='int64'),
#  ('ANI Pharmaceuticals, Inc.',
#   'Health Care',
#   'No Industry Identified'): Int64Index([214], dtype='int64'),
#  ('Anika Therapeutics Inc.',
#   'Health Care',
#   'No Industry Identified'): Int64Index([215], dtype='int64'),
#  ('Anixa Biosciences, Inc.',
#   'Health Care',
#   'No Industry Identified'): Int64Index([216], dtype='int64'),
#  ('ANSYS, Inc.',
#   'Technology',
#   'No Industry Identified'): Int64Index([217], dtype='int64'),
#  ('Antares Pharma, Inc.',
#   'Health Care',
#   'No Industry Identified'): Int64Index([218], dtype='int64'),
#  ('Apellis Pharmaceuticals, Inc.',
#   'Health Care',
#   'No Industry Identified'): Int64Index([219], dtype='int64'),
#  ('Apogee Enterprises, Inc.',
#   'Capital Goods',
#   'No Industry Identified'): Int64Index([220], dtype='int64'),
#  ('Apollo Endosurgery, Inc.',
#   'Health Care',
#   'No Industry Identified'): Int64Index([221], dtype='int64'),
#  ('Apollo Investment Corporation',
#   nan,
#   'No Industry Identified'): Int64Index([222], dtype='int64'),
#  ('Apollo Medical Holdings, Inc.',
#   'Consumer Services',
#   'No Industry Identified'): Int64Index([223], dtype='int64'),
#  ('AppFolio, Inc.',
#   'Technology',
#   'No Industry Identified'): Int64Index([224], dtype='int64'),
#  ('Appian Corporation',
#   'Technology',
#   'No Industry Identified'): Int64Index([225], dtype='int64'),
#  ('Apple Inc.',
#   'Technology',
#   'No Industry Identified'): Int64Index([226], dtype='int64'),
#  ('Appliance Recycling Centers of America, Inc.',
#   'Consumer Services',
#   'No Industry Identified'): Int64Index([227], dtype='int64'),
#  ('Applied DNA Sciences Inc',
#   'Consumer Services',
#   'No Industry Identified'): Int64Index([228, 229], dtype='int64'),
#  ('Applied Genetic Technologies Corporation',
#   'Health Care',
#   'No Industry Identified'): Int64Index([230], dtype='int64'),
#  ('Applied Materials, Inc.',
#   'Technology',
#   'No Industry Identified'): Int64Index([231], dtype='int64'),
#  ('Applied Optoelectronics, Inc.',
#   'Technology',
#   'No Industry Identified'): Int64Index([232], dtype='int64'),
#  ('Applied Therapeutics, Inc.',
#   'Health Care',
#   'No Industry Identified'): Int64Index([233], dtype='int64'),
#  ('Approach Resources Inc.',
#   'Energy',
#   'No Industry Identified'): Int64Index([234], dtype='int64'),
#  ('Aptevo Therapeutics Inc.',
#   'Health Care',
#   'No Industry Identified'): Int64Index([235], dtype='int64'),
#  ('Aptinyx Inc.',
#   'Health Care',
#   'No Industry Identified'): Int64Index([236], dtype='int64'),
#  ('Aptorum Group Limited',
#   'Health Care',
#   'No Industry Identified'): Int64Index([237], dtype='int64'),
#  ('Aptose Biosciences, Inc.',
#   'Health Care',
#   'No Industry Identified'): Int64Index([238], dtype='int64'),
#  ('Apyx Medical Corporation',
#   'Health Care',
#   'No Industry Identified'): Int64Index([239], dtype='int64'),
#  ('Aqua Metals, Inc.',
#   'Basic Industries',
#   'No Industry Identified'): Int64Index([240], dtype='int64'),
#  ('AquaBounty Technologies, Inc.',
#   nan,
#   'No Industry Identified'): Int64Index([241], dtype='int64'),
#  ('Aquestive Therapeutics, Inc.',
#   'Health Care',
#   'No Industry Identified'): Int64Index([242], dtype='int64'),
#  ('Aquinox Pharmaceuticals, Inc.',
#   'Health Care',
#   'No Industry Identified'): Int64Index([243], dtype='int64'),
#  ('Aratana Therapeutics, Inc.',
#   'Health Care',
#   'No Industry Identified'): Int64Index([244], dtype='int64'),
#  ('Aravive, Inc.',
#   'Health Care',
#   'No Industry Identified'): Int64Index([245], dtype='int64'),
#  ('Arbutus Biopharma Corporation',
#   'Health Care',
#   'No Industry Identified'): Int64Index([246], dtype='int64'),
#  ('ARC Group Worldwide, Inc.',
#   'Capital Goods',
#   'No Industry Identified'): Int64Index([247], dtype='int64'),
#  ('ARCA biopharma, Inc.',
#   'Health Care',
#   'No Industry Identified'): Int64Index([248], dtype='int64'),
#  ('Arcadia Biosciences, Inc.',
#   'Basic Industries',
#   'No Industry Identified'): Int64Index([249], dtype='int64'),
#  ('ArcBest Corporation',
#   'Transportation',
#   'No Industry Identified'): Int64Index([250], dtype='int64'),
#  ('Arch Capital Group Ltd.',
#   'Finance',
#   'No Industry Identified'): Int64Index([251, 252, 253], dtype='int64'),
#  ('Arcimoto, Inc.',
#   'Consumer Non-Durables',
#   'No Industry Identified'): Int64Index([254], dtype='int64'),
#  ('Arco Platform Limited',
#   'Consumer Services',
#   'No Industry Identified'): Int64Index([255], dtype='int64'),
#  ('Arcturus Therapeutics Ltd.',
#   'Health Care',
#   'No Industry Identified'): Int64Index([256], dtype='int64'),
#  ('Ardelyx, Inc.',
#   'Health Care',
#   'No Industry Identified'): Int64Index([257], dtype='int64'),
#  ('Arena Pharmaceuticals, Inc.',
#   'Health Care',
#   'No Industry Identified'): Int64Index([258], dtype='int64'),
#  ('Ares Capital Corporation',
#   nan,
#   'No Industry Identified'): Int64Index([259], dtype='int64'),
#  ('argenx SE',
#   'Health Care',
#   'No Industry Identified'): Int64Index([260], dtype='int64'),
#  ('Aridis Pharmaceuticals Inc.',
#   'Health Care',
#   'No Industry Identified'): Int64Index([261], dtype='int64'),
#  ('Ark Restaurants Corp.',
#   'Consumer Services',
#   'No Industry Identified'): Int64Index([262], dtype='int64'),
#  ('Arotech Corporation',
#   'Miscellaneous',
#   'No Industry Identified'): Int64Index([263], dtype='int64'),
#  ('ArQule, Inc.',
#   'Health Care',
#   'No Industry Identified'): Int64Index([264], dtype='int64'),
#  ('Array BioPharma Inc.',
#   'Health Care',
#   'No Industry Identified'): Int64Index([265], dtype='int64'),
#  ('Arrow DWA Country Rotation ETF',
#   nan,
#   'No Industry Identified'): Int64Index([266], dtype='int64'),
#  ('Arrow DWA Tactical ETF',
#   nan,
#   'No Industry Identified'): Int64Index([267], dtype='int64'),
#  ('Arrow Financial Corporation',
#   'Finance',
#   'No Industry Identified'): Int64Index([268], dtype='int64'),
#  ('Arrowhead Pharmaceuticals, Inc.',
#   'Health Care',
#   'No Industry Identified'): Int64Index([269], dtype='int64'),
#  ('Artesian Resources Corporation',
#   'Public Utilities',
#   'No Industry Identified'): Int64Index([270], dtype='int64'),
#  ('Art&#39;s-Way Manufacturing Co., Inc.',
#   'Capital Goods',
#   'No Industry Identified'): Int64Index([271], dtype='int64'),
#  ('Arvinas, Inc.',
#   'Health Care',
#   'No Industry Identified'): Int64Index([272], dtype='int64'),
#  ('ARYA Sciences Acquisition Corp.',
#   'Finance',
#   'No Industry Identified'): Int64Index([273, 274, 275], dtype='int64'),
#  ('Ascena Retail Group, Inc.',
#   'Consumer Services',
#   'No Industry Identified'): Int64Index([276], dtype='int64'),
#  ('Ascendis Pharma A/S',
#   'Health Care',
#   'No Industry Identified'): Int64Index([277], dtype='int64'),
#  ('Ascent Capital Group, Inc.',
#   'Consumer Services',
#   'No Industry Identified'): Int64Index([278], dtype='int64'),
#  ('Asia Pacific Wire & Cable Corporation Limited',
#   'Basic Industries',
#   'No Industry Identified'): Int64Index([279], dtype='int64'),
#  ('ASLAN Pharmaceuticals Limited',
#   'Health Care',
#   'No Industry Identified'): Int64Index([280], dtype='int64'),
#  ('ASML Holding N.V.',
#   'Technology',
#   'No Industry Identified'): Int64Index([281], dtype='int64'),
#  ('Aspen Group Inc.',
#   'Consumer Services',
#   'No Industry Identified'): Int64Index([282], dtype='int64'),
#  ('Aspen Technology, Inc.',
#   'Technology',
#   'No Industry Identified'): Int64Index([283], dtype='int64'),
#  ('Assembly Biosciences, Inc.',
#   'Health Care',
#   'No Industry Identified'): Int64Index([284], dtype='int64'),
#  ('Assertio Therapeutics, Inc.',
#   'Health Care',
#   'No Industry Identified'): Int64Index([285], dtype='int64'),
#  ('Asta Funding, Inc.',
#   'Finance',
#   'No Industry Identified'): Int64Index([286], dtype='int64'),
#  ('Astec Industries, Inc.',
#   'Capital Goods',
#   'No Industry Identified'): Int64Index([287], dtype='int64'),
#  ('Astronics Corporation',
#   'Capital Goods',
#   'No Industry Identified'): Int64Index([288], dtype='int64'),
#  ('AstroNova, Inc.',
#   'Technology',
#   'No Industry Identified'): Int64Index([289], dtype='int64'),
#  ('Astrotech Corporation',
#   'Capital Goods',
#   'No Industry Identified'): Int64Index([290], dtype='int64'),
#  ('Asure Software Inc',
#   'Technology',
#   'No Industry Identified'): Int64Index([291], dtype='int64'),
#  ('ASV Holdings, Inc.',
#   'Capital Goods',
#   'No Industry Identified'): Int64Index([292], dtype='int64'),
#  ('ATA Inc.',
#   'Consumer Services',
#   'No Industry Identified'): Int64Index([293], dtype='int64'),
#  ('Atara Biotherapeutics, Inc.',
#   'Health Care',
#   'No Industry Identified'): Int64Index([294], dtype='int64'),
#  ('Athenex, Inc.',
#   'Health Care',
#   'No Industry Identified'): Int64Index([295], dtype='int64'),
#  ('Athersys, Inc.',
#   'Health Care',
#   'No Industry Identified'): Int64Index([296], dtype='int64'),
#  ('ATIF Holdings Limited',
#   'Consumer Services',
#   'No Industry Identified'): Int64Index([297], dtype='int64'),
#  ('Atlantic American Corporation',
#   'Finance',
#   'No Industry Identified'): Int64Index([298], dtype='int64'),
#  ('Atlantic Capital Bancshares, Inc.',
#   'Finance',
#   'No Industry Identified'): Int64Index([299], dtype='int64'),
#  ('Atlantic Union Bankshares Corporation',
#   'Finance',
#   'No Industry Identified'): Int64Index([300], dtype='int64'),
#  ('Atlantica Yield plc',
#   'Public Utilities',
#   'No Industry Identified'): Int64Index([301], dtype='int64'),
#  ('Atlanticus Holdings Corporation',
#   'Finance',
#   'No Industry Identified'): Int64Index([302], dtype='int64'),
#  ('Atlas Air Worldwide Holdings',
#   'Transportation',
#   'No Industry Identified'): Int64Index([303], dtype='int64'),
#  ('Atlas Financial Holdings, Inc.',
#   'Finance',
#   'No Industry Identified'): Int64Index([304, 305], dtype='int64'),
#  ('Atlassian Corporation Plc',
#   'Technology',
#   'No Industry Identified'): Int64Index([306], dtype='int64'),
#  ('ATN International, Inc.',
#   'Public Utilities',
#   'No Industry Identified'): Int64Index([307], dtype='int64'),
#  ('Atomera Incorporated',
#   'Technology',
#   'No Industry Identified'): Int64Index([308], dtype='int64'),
#  ('Atossa Genetics Inc.',
#   'Health Care',
#   'No Industry Identified'): Int64Index([309], dtype='int64'),
#  ('AtriCure, Inc.',
#   'Health Care',
#   'No Industry Identified'): Int64Index([310], dtype='int64'),
#  ('Atrion Corporation',
#   'Health Care',
#   'No Industry Identified'): Int64Index([311], dtype='int64'),
#  ('Attis Industries Inc.',
#   'Basic Industries',
#   'No Industry Identified'): Int64Index([312, 313], dtype='int64'),
#  ('aTyr Pharma, Inc.',
#   'Health Care',
#   'No Industry Identified'): Int64Index([314], dtype='int64'),
#  ('Auburn National Bancorporation, Inc.',
#   'Finance',
#   'No Industry Identified'): Int64Index([315], dtype='int64'),
#  ('Audentes Therapeutics, Inc.',
#   'Health Care',
#   'No Industry Identified'): Int64Index([316], dtype='int64'),
#  ('AudioCodes Ltd.',
#   'Public Utilities',
#   'No Industry Identified'): Int64Index([317], dtype='int64'),
#  ('AudioEye, Inc.',
#   'Technology',
#   'No Industry Identified'): Int64Index([318], dtype='int64'),
#  ('Aurinia Pharmaceuticals Inc',
#   'Health Care',
#   'No Industry Identified'): Int64Index([319], dtype='int64'),
#  ('Auris Medical Holding Ltd.',
#   'Health Care',
#   'No Industry Identified'): Int64Index([320], dtype='int64'),
#  ('Aurora Mobile Limited',
#   'Technology',
#   'No Industry Identified'): Int64Index([321], dtype='int64'),
#  ('Autodesk, Inc.',
#   'Technology',
#   'No Industry Identified'): Int64Index([322], dtype='int64'),
#  ('Autolus Therapeutics plc',
#   'Health Care',
#   'No Industry Identified'): Int64Index([323], dtype='int64'),
#  ('Automatic Data Processing, Inc.',
#   'Technology',
#   'No Industry Identified'): Int64Index([324], dtype='int64'),
#  ('AutoWeb, Inc.',
#   'Technology',
#   'No Industry Identified'): Int64Index([325], dtype='int64'),
#  ('Avadel Pharmaceuticals plc',
#   'Health Care',
#   'No Industry Identified'): Int64Index([326], dtype='int64'),
#  ('Avalon GloboCare Corp.',
#   'Consumer Services',
#   'No Industry Identified'): Int64Index([327], dtype='int64'),
#  ('Avedro, Inc',
#   'Health Care',
#   'No Industry Identified'): Int64Index([328], dtype='int64'),
#  ('Avenue Therapeutics, Inc.',
#   'Health Care',
#   'No Industry Identified'): Int64Index([329], dtype='int64'),
#  ('AVEO Pharmaceuticals, Inc.',
#   'Health Care',
#   'No Industry Identified'): Int64Index([330], dtype='int64'),
#  ('Aviat Networks, Inc.',
#   'Technology',
#   'No Industry Identified'): Int64Index([331], dtype='int64'),
#  ('Avid Bioservices, Inc.',
#   'Health Care',
#   'No Industry Identified'): Int64Index([332, 333], dtype='int64'),
#  ('Avid Technology, Inc.',
#   'Technology',
#   'No Industry Identified'): Int64Index([334], dtype='int64'),
#  ('Avinger, Inc.',
#   'Health Care',
#   'No Industry Identified'): Int64Index([335], dtype='int64'),
#  ('Avis Budget Group, Inc.',
#   'Consumer Services',
#   'No Industry Identified'): Int64Index([336], dtype='int64'),
#  ('Avnet, Inc.',
#   'Technology',
#   'No Industry Identified'): Int64Index([337], dtype='int64'),
#  ('AVROBIO, Inc.',
#   'Health Care',
#   'No Industry Identified'): Int64Index([338], dtype='int64'),
#  ('Aware, Inc.',
#   'Technology',
#   'No Industry Identified'): Int64Index([339], dtype='int64'),
#  ('Axcelis Technologies, Inc.',
#   'Technology',
#   'No Industry Identified'): Int64Index([340], dtype='int64'),
#  ('Axcella Health Inc.',
#   'Health Care',
#   'No Industry Identified'): Int64Index([341], dtype='int64'),
#  ('AxoGen, Inc.',
#   'Health Care',
#   'No Industry Identified'): Int64Index([342], dtype='int64'),
#  ('Axon Enterprise, Inc.',
#   'Capital Goods',
#   'No Industry Identified'): Int64Index([343], dtype='int64'),
#  ('Axonics Modulation Technologies, Inc.',
#   'Health Care',
#   'No Industry Identified'): Int64Index([344], dtype='int64'),
#  ('Axovant Gene Therapies Ltd.',
#   'Health Care',
#   'No Industry Identified'): Int64Index([345], dtype='int64'),
#  ('Axsome Therapeutics, Inc.',
#   'Health Care',
#   'No Industry Identified'): Int64Index([346], dtype='int64'),
#  ('AXT Inc',
#   'Technology',
#   'No Industry Identified'): Int64Index([347], dtype='int64'),
#  ('Aytu BioScience, Inc.',
#   'Health Care',
#   'No Industry Identified'): Int64Index([348], dtype='int64'),
#  ('AzurRx BioPharma, Inc.',
#   'Health Care',
#   'No Industry Identified'): Int64Index([349], dtype='int64'),
#  ('B Communications Ltd.',
#   'Consumer Services',
#   'No Industry Identified'): Int64Index([350], dtype='int64'),
#  ('B. Riley Financial, Inc.',
#   'Miscellaneous',
#   'No Industry Identified'): Int64Index([351, 352, 353, 354, 355, 356, 357], dtype='int64'),
#  ('B.O.S. Better Online Solutions',
#   'Technology',
#   'No Industry Identified'): Int64Index([358], dtype='int64'),
#  ('Baidu, Inc.',
#   'Technology',
#   'No Industry Identified'): Int64Index([359], dtype='int64'),
#  ('Balchem Corporation',
#   'Basic Industries',
#   'No Industry Identified'): Int64Index([360], dtype='int64'),
#  ('Ballard Power Systems, Inc.',
#   'Energy',
#   'No Industry Identified'): Int64Index([361], dtype='int64'),
#  ('BancFirst Corporation',
#   'Finance',
#   'No Industry Identified'): Int64Index([362, 363], dtype='int64'),
#  ('Bancorp 34, Inc.',
#   'Finance',
#   'No Industry Identified'): Int64Index([364], dtype='int64'),
#  ('Bandwidth Inc.',
#   'Technology',
#   'No Industry Identified'): Int64Index([365], dtype='int64'),
#  ('Bank First National Corporation',
#   'Finance',
#   'No Industry Identified'): Int64Index([366], dtype='int64'),
#  ('Bank of Commerce Holdings (CA)',
#   'Finance',
#   'No Industry Identified'): Int64Index([367], dtype='int64'),
#  ('Bank of Marin Bancorp',
#   'Finance',
#   'No Industry Identified'): Int64Index([368], dtype='int64'),
#  ('Bank Of Montreal',
#   'Finance',
#   'No Industry Identified'): Int64Index([369], dtype='int64'),
#  ('Bank of South Carolina Corp.',
#   'Finance',
#   'No Industry Identified'): Int64Index([370], dtype='int64'),
#  ('Bank of the James Financial Group, Inc.',
#   'Finance',
#   'No Industry Identified'): Int64Index([371], dtype='int64'),
#  ('Bank OZK',
#   'Finance',
#   'No Industry Identified'): Int64Index([372], dtype='int64'),
#  ('Bank7 Corp.',
#   'Finance',
#   'No Industry Identified'): Int64Index([373], dtype='int64'),
#  ('BankFinancial Corporation',
#   'Finance',
#   'No Industry Identified'): Int64Index([374], dtype='int64'),
#  ('BankFlorida',
#   nan,
#   'No Industry Identified'): Int64Index([375], dtype='int64'),
#  ('Bankwell Financial Group, Inc.',
#   'Finance',
#   'No Industry Identified'): Int64Index([376], dtype='int64'),
#  ('Banner Corporation',
#   'Finance',
#   'No Industry Identified'): Int64Index([377], dtype='int64'),
#  ('Baozun Inc.',
#   'Consumer Services',
#   'No Industry Identified'): Int64Index([378], dtype='int64'),
#  ('Barclays PLC',
#   nan,
#   'No Industry Identified'): Int64Index([379, 380, 381, 382, 383, 384, 385, 386, 387, 388], dtype='int64'),
#  ('Barrett Business Services, Inc.',
#   'Technology',
#   'No Industry Identified'): Int64Index([389], dtype='int64'),
#  ('Barrick Gold Corporation',
#   'Basic Industries',
#   'No Industry Identified'): Int64Index([390], dtype='int64'),
#  ('Bassett Furniture Industries, Incorporated',
#   'Consumer Durables',
#   'No Industry Identified'): Int64Index([391], dtype='int64'),
#  ('BATS BZX Exchange',
#   nan,
#   'No Industry Identified'): Int64Index([392], dtype='int64'),
#  ('BayCom Corp',
#   'Finance',
#   'No Industry Identified'): Int64Index([393], dtype='int64'),
#  ('BCB Bancorp, Inc. (NJ)',
#   'Finance',
#   'No Industry Identified'): Int64Index([394], dtype='int64'),
#  ('Beacon Roofing Supply, Inc.',
#   'Consumer Services',
#   'No Industry Identified'): Int64Index([395], dtype='int64'),
#  ('Beasley Broadcast Group, Inc.',
#   'Consumer Services',
#   'No Industry Identified'): Int64Index([396], dtype='int64'),
#  ('Bed Bath & Beyond Inc.',
#   'Consumer Services',
#   'No Industry Identified'): Int64Index([397], dtype='int64'),
#  ('BeiGene, Ltd.',
#   'Health Care',
#   'No Industry Identified'): Int64Index([398], dtype='int64'),
#  ('Bel Fuse Inc.',
#   'Capital Goods',
#   'No Industry Identified'): Int64Index([399, 400], dtype='int64'),
#  ('Bellerophon Therapeutics, Inc.',
#   'Health Care',
#   'No Industry Identified'): Int64Index([401], dtype='int64'),
#  ('Bellicum Pharmaceuticals, Inc.',
#   'Health Care',
#   'No Industry Identified'): Int64Index([402], dtype='int64'),
#  ('Benefitfocus, Inc.',
#   'Technology',
#   'No Industry Identified'): Int64Index([403], dtype='int64'),
#  ('Benitec Biopharma Limited',
#   'Health Care',
#   'No Industry Identified'): Int64Index([404, 405], dtype='int64'),
#  ('Berry Petroleum Corporation',
#   'Energy',
#   'No Industry Identified'): Int64Index([406], dtype='int64'),
#  ('Beyond Meat, Inc.',
#   'Consumer Non-Durables',
#   'No Industry Identified'): Int64Index([407], dtype='int64'),
#  ('BeyondSpring, Inc.',
#   'Health Care',
#   'No Industry Identified'): Int64Index([408], dtype='int64'),
#  ('BGC Partners, Inc.',
#   'Finance',
#   'No Industry Identified'): Int64Index([409], dtype='int64'),
#  ('Bicycle Therapeutics plc',
#   'Health Care',
#   'No Industry Identified'): Int64Index([410], dtype='int64'),
#  ('Big 5 Sporting Goods Corporation',
#   'Consumer Services',
#   'No Industry Identified'): Int64Index([411], dtype='int64'),
#  ('Big Rock Partners Acquisition Corp.',
#   'Finance',
#   'No Industry Identified'): Int64Index([412, 413, 414, 415], dtype='int64'),
#  ('Bilibili Inc.',
#   'Technology',
#   'No Industry Identified'): Int64Index([416], dtype='int64'),
#  ('Bioanalytical Systems, Inc.',
#   'Health Care',
#   'No Industry Identified'): Int64Index([417], dtype='int64'),
#  ('Biocept, Inc.',
#   'Health Care',
#   'No Industry Identified'): Int64Index([418], dtype='int64'),
#  ('BioCryst Pharmaceuticals, Inc.',
#   'Health Care',
#   'No Industry Identified'): Int64Index([419], dtype='int64'),
#  ('BioDelivery Sciences International, Inc.',
#   'Health Care',
#   'No Industry Identified'): Int64Index([420], dtype='int64'),
#  ('Biofrontera AG',
#   'Health Care',
#   'No Industry Identified'): Int64Index([421], dtype='int64'),
#  ('Biogen Inc.',
#   'Health Care',
#   'No Industry Identified'): Int64Index([422], dtype='int64'),
#  ('BioHiTech Global, Inc.',
#   'Consumer Services',
#   'No Industry Identified'): Int64Index([423], dtype='int64'),
#  ('BIO-key International, Inc.',
#   'Technology',
#   'No Industry Identified'): Int64Index([424], dtype='int64'),
#  ('Biolase, Inc.',
#   'Health Care',
#   'No Industry Identified'): Int64Index([425], dtype='int64'),
#  ('BioLife Solutions, Inc.',
#   'Health Care',
#   'No Industry Identified'): Int64Index([426], dtype='int64'),
#  ('BioLineRx Ltd.',
#   'Health Care',
#   'No Industry Identified'): Int64Index([427], dtype='int64'),
#  ('BioMarin Pharmaceutical Inc.',
#   'Health Care',
#   'No Industry Identified'): Int64Index([428], dtype='int64'),
#  ('Biomerica, Inc.',
#   'Health Care',
#   'No Industry Identified'): Int64Index([429], dtype='int64'),
#  ('Bionano Genomics, Inc.',
#   'Capital Goods',
#   'No Industry Identified'): Int64Index([430, 431], dtype='int64'),
#  ('BiondVax Pharmaceuticals Ltd.',
#   'Health Care',
#   'No Industry Identified'): Int64Index([432, 433], dtype='int64'),
#  ('Bionik Laboratories Corp.',
#   nan,
#   'No Industry Identified'): Int64Index([434], dtype='int64'),
#  ('Bio-Path Holdings, Inc.',
#   'Health Care',
#   'No Industry Identified'): Int64Index([435], dtype='int64'),
#  ('BioScrip, Inc.',
#   'Health Care',
#   'No Industry Identified'): Int64Index([436], dtype='int64'),
#  ('BioSig Technologies, Inc.',
#   'Health Care',
#   'No Industry Identified'): Int64Index([437], dtype='int64'),
#  ('BioSpecifics Technologies Corp',
#   'Health Care',
#   'No Industry Identified'): Int64Index([438], dtype='int64'),
#  ('Bio-Techne Corp',
#   'Health Care',
#   'No Industry Identified'): Int64Index([439], dtype='int64'),
#  ('BioTelemetry, Inc.',
#   'Health Care',
#   'No Industry Identified'): Int64Index([440], dtype='int64'),
#  ('BioXcel Therapeutics, Inc.',
#   'Health Care',
#   'No Industry Identified'): Int64Index([441], dtype='int64'),
#  ('BIQI International Holdings Corporation',
#   'Consumer Non-Durables',
#   'No Industry Identified'): Int64Index([442], dtype='int64'),
#  ('BJ&#39;s Restaurants, Inc.',
#   'Consumer Services',
#   'No Industry Identified'): Int64Index([443], dtype='int64'),
#  ('Black Ridge Acquisition Corp.',
#   'Consumer Services',
#   'No Industry Identified'): Int64Index([444, 445, 446, 447], dtype='int64'),
#  ('Blackbaud, Inc.',
#   'Technology',
#   'No Industry Identified'): Int64Index([448], dtype='int64'),
#  ('BlackLine, Inc.',
#   'Technology',
#   'No Industry Identified'): Int64Index([449], dtype='int64'),
#  ('BlackRock Capital Investment Corporation',
#   nan,
#   'No Industry Identified'): Int64Index([450], dtype='int64'),
#  ('BlackRock TCP Capital Corp.',
#   nan,
#   'No Industry Identified'): Int64Index([451], dtype='int64'),
#  ('Blink Charging Co.',
#   'Consumer Durables',
#   'No Industry Identified'): Int64Index([452, 453], dtype='int64'),
#  ('Bloomin&#39; Brands, Inc.',
#   'Consumer Services',
#   'No Industry Identified'): Int64Index([454], dtype='int64'),
#  ('Blucora, Inc.',
#   'Finance',
#   'No Industry Identified'): Int64Index([455], dtype='int64'),
#  ('Blue Bird Corporation',
#   'Capital Goods',
#   'No Industry Identified'): Int64Index([456], dtype='int64'),
#  ('bluebird bio, Inc.',
#   'Health Care',
#   'No Industry Identified'): Int64Index([457], dtype='int64'),
#  ('Blueknight Energy Partners L.P., L.L.C.',
#   'Energy',
#   'No Industry Identified'): Int64Index([458, 459], dtype='int64'),
#  ('Blueprint Medicines Corporation',
#   'Health Care',
#   'No Industry Identified'): Int64Index([460], dtype='int64'),
#  ('BlueStar Israel Technology ETF',
#   nan,
#   'No Industry Identified'): Int64Index([461], dtype='int64'),
#  ('BMC Stock Holdings, Inc.',
#   'Consumer Services',
#   'No Industry Identified'): Int64Index([462], dtype='int64'),
#  ('Boingo Wireless, Inc.',
#   'Consumer Services',
#   'No Industry Identified'): Int64Index([463], dtype='int64'),
#  ('BOK Financial Corporation',
#   'Finance',
#   'No Industry Identified'): Int64Index([464, 465], dtype='int64'),
#  ('Bonso Electronics International, Inc.',
#   'Capital Goods',
#   'No Industry Identified'): Int64Index([466], dtype='int64'),
#  ('Booking Holdings Inc.',
#   'Miscellaneous',
#   'No Industry Identified'): Int64Index([467], dtype='int64'),
#  ('Borqs Technologies, Inc. ',
#   'Technology',
#   'No Industry Identified'): Int64Index([468], dtype='int64'),
#  ('Boston Omaha Corporation',
#   'Finance',
#   'No Industry Identified'): Int64Index([469], dtype='int64'),
#  ('Boston Private Financial Holdings, Inc.',
#   'Finance',
#   'No Industry Identified'): Int64Index([470], dtype='int64'),
#  ('Bottomline Technologies, Inc.',
#   'Technology',
#   'No Industry Identified'): Int64Index([471], dtype='int64'),
#  ('Boxlight Corporation',
#   'Miscellaneous',
#   'No Industry Identified'): Int64Index([472], dtype='int64'),
#  ('Boxwood Merger Corp.',
#   'Finance',
#   'No Industry Identified'): Int64Index([473, 474, 475], dtype='int64'),
#  ('Braeburn Pharmaceuticals, Inc.',
#   nan,
#   'No Industry Identified'): Int64Index([476], dtype='int64'),
#  ('Brainstorm Cell Therapeutics Inc.',
#   'Health Care',
#   'No Industry Identified'): Int64Index([477], dtype='int64'),
#  ('Brainsway Ltd.',
#   'Health Care',
#   'No Industry Identified'): Int64Index([478], dtype='int64'),
#  ('Brandes Investment Trust',
#   nan,
#   'No Industry Identified'): Int64Index([479], dtype='int64'),
#  ('Bricktown Restaurant Group, Inc.',
#   nan,
#   'No Industry Identified'): Int64Index([480], dtype='int64'),
#  ('Bridge Bancorp, Inc.',
#   'Finance',
#   'No Industry Identified'): Int64Index([481], dtype='int64'),
#  ('Bridgeline Digital, Inc.',
#   'Technology',
#   'No Industry Identified'): Int64Index([482], dtype='int64'),
#  ('Bridgewater Bancshares, Inc.',
#   'Finance',
#   'No Industry Identified'): Int64Index([483], dtype='int64'),
#  ('Bridgford Foods Corporation',
#   'Consumer Non-Durables',
#   'No Industry Identified'): Int64Index([484], dtype='int64'),
#  ('Brightcove Inc.',
#   'Technology',
#   'No Industry Identified'): Int64Index([485], dtype='int64'),
#  ('Brighthouse Financial, Inc.',
#   'Finance',
#   'No Industry Identified'): Int64Index([486, 487, 488], dtype='int64'),
#  ('Broadcom Inc.',
#   'Technology',
#   'No Industry Identified'): Int64Index([489], dtype='int64'),
#  ('BroadVision, Inc.',
#   'Technology',
#   'No Industry Identified'): Int64Index([490], dtype='int64'),
#  ('Broadway Financial Corporation',
#   'Finance',
#   'No Industry Identified'): Int64Index([491], dtype='int64'),
#  ('Broadwind Energy, Inc.',
#   'Capital Goods',
#   'No Industry Identified'): Int64Index([492], dtype='int64'),
#  ('Brookfield Property Partners L.P.',
#   'Finance',
#   'No Industry Identified'): Int64Index([493, 494], dtype='int64'),
#  ('Brookfield Property REIT Inc.',
#   'Consumer Services',
#   'No Industry Identified'): Int64Index([495, 496], dtype='int64'),
#  ('Brookline Bancorp, Inc.',
#   'Finance',
#   'No Industry Identified'): Int64Index([497], dtype='int64'),
#  ('Brooks Automation, Inc.',
#   'Technology',
#   'No Industry Identified'): Int64Index([498], dtype='int64'),
#  ('BRP Inc.',
#   'Capital Goods',
#   'No Industry Identified'): Int64Index([499], dtype='int64'),
#  ('Bruker Corporation',
#   'Capital Goods',
#   'No Industry Identified'): Int64Index([500], dtype='int64'),
#  ('Bryn Mawr Bank Corporation',
#   'Finance',
#   'No Industry Identified'): Int64Index([501], dtype='int64'),
#  ('BSQUARE Corporation',
#   'Miscellaneous',
#   'No Industry Identified'): Int64Index([502], dtype='int64'),
#  ('Builders FirstSource, Inc.',
#   'Consumer Services',
#   'No Industry Identified'): Int64Index([503], dtype='int64'),
#  ('Business First Bancshares, Inc.',
#   'Finance',
#   'No Industry Identified'): Int64Index([504], dtype='int64'),
#  ('C&F Financial Corporation',
#   'Finance',
#   'No Industry Identified'): Int64Index([505], dtype='int64'),
#  ('C.H. Robinson Worldwide, Inc.',
#   'Transportation',
#   'No Industry Identified'): Int64Index([506], dtype='int64'),
#  ('Cabot Microelectronics Corporation',
#   'Technology',
#   'No Industry Identified'): Int64Index([507], dtype='int64'),
#  ('Cadence Design Systems, Inc.',
#   'Technology',
# ...
#  ('Emmis Communications Corporation',
#   'Consumer Services',
#   'No Industry Identified'): Int64Index([997], dtype='int64'),
#  ('Empire Resorts, Inc.',
#   'Consumer Services',
#   'No Industry Identified'): Int64Index([998], dtype='int64'),
#  ('Enanta Pharmaceuticals, Inc.',
#   'Health Care',
#   'No Industry Identified'): Int64Index([999], dtype='int64'),
#  ('Encore Capital Group Inc',
#   'Finance',
#   'No Industry Identified'): Int64Index([1000], dtype='int64'),
#  ('Encore Wire Corporation',
#   'Capital Goods',
#   'No Industry Identified'): Int64Index([1001], dtype='int64'),
#  ('Endo International plc',
#   'Health Care',
#   'No Industry Identified'): Int64Index([1002], dtype='int64'),
#  ('Endologix, Inc.',
#   'Health Care',
#   'No Industry Identified'): Int64Index([1003], dtype='int64'),
#  ('ENDRA Life Sciences Inc.',
#   'Health Care',
#   'No Industry Identified'): Int64Index([1004, 1005], dtype='int64'),
#  ('Endurance International Group Holdings, Inc.',
#   'Technology',
#   'No Industry Identified'): Int64Index([1006], dtype='int64'),
#  ('Energous Corporation',
#   'Technology',
#   'No Industry Identified'): Int64Index([1007], dtype='int64'),
#  ('Energy Focus, Inc.',
#   'Consumer Durables',
#   'No Industry Identified'): Int64Index([1008], dtype='int64'),
#  ('Energy Hunter Resources, Inc.',
#   nan,
#   'No Industry Identified'): Int64Index([1009], dtype='int64'),
#  ('Energy Recovery, Inc.',
#   'Technology',
#   'No Industry Identified'): Int64Index([1010], dtype='int64'),
#  ('ENGlobal Corporation',
#   'Consumer Services',
#   'No Industry Identified'): Int64Index([1011], dtype='int64'),
#  ('Enlivex Therapeutics Ltd.',
#   'Health Care',
#   'No Industry Identified'): Int64Index([1012], dtype='int64'),
#  ('Enochian Biosciences, Inc.',
#   'Health Care',
#   'No Industry Identified'): Int64Index([1013], dtype='int64'),
#  ('Enphase Energy, Inc.',
#   'Technology',
#   'No Industry Identified'): Int64Index([1014], dtype='int64'),
#  ('Enstar Group Limited',
#   'Finance',
#   'No Industry Identified'): Int64Index([1015, 1016, 1017], dtype='int64'),
#  ('Entasis Therapeutics Holdings Inc.',
#   'Health Care',
#   'No Industry Identified'): Int64Index([1018], dtype='int64'),
#  ('Entegra Financial Corp.',
#   'Finance',
#   'No Industry Identified'): Int64Index([1019], dtype='int64'),
#  ('Entegris, Inc.',
#   'Consumer Non-Durables',
#   'No Industry Identified'): Int64Index([1020], dtype='int64'),
#  ('Entera Bio Ltd.',
#   'Health Care',
#   'No Industry Identified'): Int64Index([1021, 1022], dtype='int64'),
#  ('Enterprise Bancorp Inc',
#   'Finance',
#   'No Industry Identified'): Int64Index([1023], dtype='int64'),
#  ('Enterprise Financial Services Corporation',
#   'Finance',
#   'No Industry Identified'): Int64Index([1024], dtype='int64'),
#  ('Envision Solar International, Inc.',
#   'Technology',
#   'No Industry Identified'): Int64Index([1025, 1026], dtype='int64'),
#  ('Epizyme, Inc.',
#   'Health Care',
#   'No Industry Identified'): Int64Index([1027], dtype='int64'),
#  ('ePlus inc.',
#   'Technology',
#   'No Industry Identified'): Int64Index([1028], dtype='int64'),
#  ('Epsilon Energy Ltd.',
#   'Energy',
#   'No Industry Identified'): Int64Index([1029], dtype='int64'),
#  ('Equillium, Inc.',
#   'Health Care',
#   'No Industry Identified'): Int64Index([1030], dtype='int64'),
#  ('Equinix, Inc.',
#   'Consumer Services',
#   'No Industry Identified'): Int64Index([1031], dtype='int64'),
#  ('Equity Bancshares, Inc.',
#   'Finance',
#   'No Industry Identified'): Int64Index([1032], dtype='int64'),
#  ('Ericsson',
#   'Technology',
#   'No Industry Identified'): Int64Index([1033], dtype='int64'),
#  ('Erie Indemnity Company',
#   'Finance',
#   'No Industry Identified'): Int64Index([1034], dtype='int64'),
#  ('Erytech Pharma S.A.',
#   'Health Care',
#   'No Industry Identified'): Int64Index([1035], dtype='int64'),
#  ('Escalade, Incorporated',
#   'Consumer Non-Durables',
#   'No Industry Identified'): Int64Index([1036], dtype='int64'),
#  ('Esperion Therapeutics, Inc.',
#   'Health Care',
#   'No Industry Identified'): Int64Index([1037], dtype='int64'),
#  ('Esquire Financial Holdings, Inc.',
#   'Finance',
#   'No Industry Identified'): Int64Index([1038], dtype='int64'),
#  ('ESSA Bancorp, Inc.',
#   'Finance',
#   'No Industry Identified'): Int64Index([1039], dtype='int64'),
#  ('ESSA Pharma Inc.',
#   'Health Care',
#   'No Industry Identified'): Int64Index([1040], dtype='int64'),
#  ('Establishment Labs Holdings Inc.',
#   'Health Care',
#   'No Industry Identified'): Int64Index([1041], dtype='int64'),
#  ('Estre Ambiental, Inc.',
#   'Public Utilities',
#   'No Industry Identified'): Int64Index([1042, 1043], dtype='int64'),
#  ('ETF Series Solutions Trust Vident Core U.S. Bond Strategy Fund',
#   nan,
#   'No Industry Identified'): Int64Index([1044], dtype='int64'),
#  ('ETF Series Solutions Trust Vident Core US Equity ETF',
#   nan,
#   'No Industry Identified'): Int64Index([1045], dtype='int64'),
#  ('ETF Series Solutions Trust Vident International Equity Fund',
#   nan,
#   'No Industry Identified'): Int64Index([1046], dtype='int64'),
#  ('Eton Pharmaceuticals, Inc.',
#   'Health Care',
#   'No Industry Identified'): Int64Index([1047], dtype='int64'),
#  ('Etsy, Inc.',
#   'Miscellaneous',
#   'No Industry Identified'): Int64Index([1048], dtype='int64'),
#  ('Euro Tech Holdings Company Limited',
#   'Consumer Durables',
#   'No Industry Identified'): Int64Index([1049], dtype='int64'),
#  ('EuroDry Ltd.',
#   'Consumer Services',
#   'No Industry Identified'): Int64Index([1050], dtype='int64'),
#  ('Euronet Worldwide, Inc.',
#   'Finance',
#   'No Industry Identified'): Int64Index([1051], dtype='int64'),
#  ('Euroseas Ltd.',
#   'Transportation',
#   'No Industry Identified'): Int64Index([1052], dtype='int64'),
#  ('Evelo Biosciences, Inc.',
#   'Health Care',
#   'No Industry Identified'): Int64Index([1053], dtype='int64'),
#  ('Everbridge, Inc.',
#   'Technology',
#   'No Industry Identified'): Int64Index([1054], dtype='int64'),
#  ('Ever-Glory International Group, Inc.',
#   'Consumer Non-Durables',
#   'No Industry Identified'): Int64Index([1055], dtype='int64'),
#  ('EverQuote, Inc.',
#   'Technology',
#   'No Industry Identified'): Int64Index([1056], dtype='int64'),
#  ('Everspin Technologies, Inc.',
#   'Technology',
#   'No Industry Identified'): Int64Index([1057], dtype='int64'),
#  ('EVINE Live Inc.',
#   'Consumer Services',
#   'No Industry Identified'): Int64Index([1058], dtype='int64'),
#  ('EVO Payments, Inc.',
#   'Miscellaneous',
#   'No Industry Identified'): Int64Index([1059], dtype='int64'),
#  ('Evofem Biosciences, Inc.',
#   'Health Care',
#   'No Industry Identified'): Int64Index([1060], dtype='int64'),
#  ('Evogene Ltd.',
#   'Basic Industries',
#   'No Industry Identified'): Int64Index([1061], dtype='int64'),
#  ('Evoke Pharma, Inc.',
#   'Health Care',
#   'No Industry Identified'): Int64Index([1062], dtype='int64'),
#  ('Evolus, Inc.',
#   'Health Care',
#   'No Industry Identified'): Int64Index([1063], dtype='int64'),
#  ('Evolving Systems, Inc.',
#   'Technology',
#   'No Industry Identified'): Int64Index([1064], dtype='int64'),
#  ('Exact Sciences Corporation',
#   'Health Care',
#   'No Industry Identified'): Int64Index([1065], dtype='int64'),
#  ('Exchange Traded Concepts Trust FLAG-Forensic Accounting Long-S',
#   nan,
#   'No Industry Identified'): Int64Index([1066], dtype='int64'),
#  ('Exchange Traded Concepts Trust ROBO Global Robotics and Automa',
#   nan,
#   'No Industry Identified'): Int64Index([1067], dtype='int64'),
#  ('Exela Technologies, Inc.',
#   'Miscellaneous',
#   'No Industry Identified'): Int64Index([1068], dtype='int64'),
#  ('Exelixis, Inc.',
#   'Health Care',
#   'No Industry Identified'): Int64Index([1069], dtype='int64'),
#  ('EXFO Inc',
#   'Capital Goods',
#   'No Industry Identified'): Int64Index([1070], dtype='int64'),
#  ('ExlService Holdings, Inc.',
#   'Miscellaneous',
#   'No Industry Identified'): Int64Index([1071], dtype='int64'),
#  ('eXp World Holdings, Inc.',
#   'Finance',
#   'No Industry Identified'): Int64Index([1072], dtype='int64'),
#  ('Expedia Group, Inc.',
#   'Consumer Services',
#   'No Industry Identified'): Int64Index([1073], dtype='int64'),
#  ('Expeditors International of Washington, Inc.',
#   'Transportation',
#   'No Industry Identified'): Int64Index([1074], dtype='int64'),
#  ('Exponent, Inc.',
#   'Consumer Services',
#   'No Industry Identified'): Int64Index([1075], dtype='int64'),
#  ('Extended Stay America, Inc.',
#   'Consumer Services',
#   'No Industry Identified'): Int64Index([1076], dtype='int64'),
#  ('Extraction Oil & Gas, Inc.',
#   'Energy',
#   'No Industry Identified'): Int64Index([1077], dtype='int64'),
#  ('Extreme Networks, Inc.',
#   'Technology',
#   'No Industry Identified'): Int64Index([1078], dtype='int64'),
#  ('Eyegate Pharmaceuticals, Inc.',
#   'Health Care',
#   'No Industry Identified'): Int64Index([1079, 1080], dtype='int64'),
#  ('Eyenovia, Inc.',
#   'Health Care',
#   'No Industry Identified'): Int64Index([1081], dtype='int64'),
#  ('EyePoint Pharmaceuticals, Inc.',
#   'Capital Goods',
#   'No Industry Identified'): Int64Index([1082], dtype='int64'),
#  ('EZCORP, Inc.',
#   'Consumer Services',
#   'No Industry Identified'): Int64Index([1083], dtype='int64'),
#  ('F5 Networks, Inc.',
#   'Technology',
#   'No Industry Identified'): Int64Index([1084], dtype='int64'),
#  ('Facebook, Inc.',
#   'Technology',
#   'No Industry Identified'): Int64Index([1085], dtype='int64'),
#  ('Falcon Minerals Corporation',
#   'Energy',
#   'No Industry Identified'): Int64Index([1086, 1087], dtype='int64'),
#  ('Famous Dave&#39;s of America, Inc.',
#   'Consumer Services',
#   'No Industry Identified'): Int64Index([1088], dtype='int64'),
#  ('Fanhua Inc.',
#   'Finance',
#   'No Industry Identified'): Int64Index([1089], dtype='int64'),
#  ('Farmer Brothers Company',
#   'Consumer Non-Durables',
#   'No Industry Identified'): Int64Index([1090], dtype='int64'),
#  ('Farmers & Merchants Bancorp, Inc.',
#   'Finance',
#   'No Industry Identified'): Int64Index([1091], dtype='int64'),
#  ('Farmers National Banc Corp.',
#   'Finance',
#   'No Industry Identified'): Int64Index([1092], dtype='int64'),
#  ('FARMMI, INC.',
#   'Consumer Non-Durables',
#   'No Industry Identified'): Int64Index([1093], dtype='int64'),
#  ('FARO Technologies, Inc.',
#   'Capital Goods',
#   'No Industry Identified'): Int64Index([1094], dtype='int64'),
#  ('Fastenal Company',
#   'Consumer Services',
#   'No Industry Identified'): Int64Index([1095], dtype='int64'),
#  ('FAT Brands Inc.',
#   'Consumer Services',
#   'No Industry Identified'): Int64Index([1096], dtype='int64'),
#  ('Fate Therapeutics, Inc.',
#   'Health Care',
#   'No Industry Identified'): Int64Index([1097], dtype='int64'),
#  ('Fauquier Bankshares, Inc.',
#   'Finance',
#   'No Industry Identified'): Int64Index([1098], dtype='int64'),
#  ('FedNat Holding Company',
#   'Finance',
#   'No Industry Identified'): Int64Index([1099], dtype='int64'),
#  ('Fennec Pharmaceuticals Inc.',
#   'Health Care',
#   'No Industry Identified'): Int64Index([1100], dtype='int64'),
#  ('Ferroglobe PLC',
#   'Capital Goods',
#   'No Industry Identified'): Int64Index([1101], dtype='int64'),
#  ('FFBW, Inc.',
#   'Finance',
#   'No Industry Identified'): Int64Index([1102], dtype='int64'),
#  ('Fibrocell Science Inc.',
#   'Health Care',
#   'No Industry Identified'): Int64Index([1103], dtype='int64'),
#  ('FibroGen, Inc',
#   'Health Care',
#   'No Industry Identified'): Int64Index([1104], dtype='int64'),
#  ('Fidelity D & D Bancorp, Inc.',
#   'Finance',
#   'No Industry Identified'): Int64Index([1105], dtype='int64'),
#  ('Fidelity Nasdaq Composite Index Tracking Stock',
#   nan,
#   'No Industry Identified'): Int64Index([1106], dtype='int64'),
#  ('Fidelity Southern Corporation',
#   'Finance',
#   'No Industry Identified'): Int64Index([1107], dtype='int64'),
#  ('Fidus Investment Corporation',
#   nan,
#   'No Industry Identified'): Int64Index([1108, 1109, 1110], dtype='int64'),
#  ('Fiesta Restaurant Group, Inc.',
#   'Consumer Services',
#   'No Industry Identified'): Int64Index([1111], dtype='int64'),
#  ('Fifth Third Bancorp',
#   'Finance',
#   'No Industry Identified'): Int64Index([1112, 1113], dtype='int64'),
#  ('Financial Institutions, Inc.',
#   'Finance',
#   'No Industry Identified'): Int64Index([1114], dtype='int64'),
#  ('Finisar Corporation',
#   'Technology',
#   'No Industry Identified'): Int64Index([1115], dtype='int64'),
#  ('Finjan Holdings, Inc.',
#   'Miscellaneous',
#   'No Industry Identified'): Int64Index([1116], dtype='int64'),
#  ('FinTech Acquisition Corp. III',
#   'Finance',
#   'No Industry Identified'): Int64Index([1117, 1118, 1119], dtype='int64'),
#  ('FireEye, Inc.',
#   'Technology',
#   'No Industry Identified'): Int64Index([1120], dtype='int64'),
#  ('First Bancorp',
#   'Finance',
#   'No Industry Identified'): Int64Index([1121], dtype='int64'),
#  ('First Bancorp, Inc (ME)',
#   'Finance',
#   'No Industry Identified'): Int64Index([1122], dtype='int64'),
#  ('First Bank',
#   nan,
#   'No Industry Identified'): Int64Index([1123], dtype='int64'),
#  ('First Busey Corporation',
#   'Finance',
#   'No Industry Identified'): Int64Index([1124], dtype='int64'),
#  ('First Business Financial Services, Inc.',
#   'Finance',
#   'No Industry Identified'): Int64Index([1125], dtype='int64'),
#  ('First Capital, Inc.',
#   'Finance',
#   'No Industry Identified'): Int64Index([1126], dtype='int64'),
#  ('First Choice Bancorp',
#   'Finance',
#   'No Industry Identified'): Int64Index([1127], dtype='int64'),
#  ('First Citizens BancShares, Inc.',
#   'Finance',
#   'No Industry Identified'): Int64Index([1128], dtype='int64'),
#  ('First Community Bankshares, Inc.',
#   'Finance',
#   'No Industry Identified'): Int64Index([1129], dtype='int64'),
#  ('First Community Corporation',
#   'Finance',
#   'No Industry Identified'): Int64Index([1130], dtype='int64'),
#  ('First Defiance Financial Corp.',
#   'Finance',
#   'No Industry Identified'): Int64Index([1131], dtype='int64'),
#  ('First Financial Bancorp.',
#   'Finance',
#   'No Industry Identified'): Int64Index([1132], dtype='int64'),
#  ('First Financial Bankshares, Inc.',
#   'Finance',
#   'No Industry Identified'): Int64Index([1133], dtype='int64'),
#  ('First Financial Corporation Indiana',
#   'Finance',
#   'No Industry Identified'): Int64Index([1134], dtype='int64'),
#  ('First Financial Northwest, Inc.',
#   'Finance',
#   'No Industry Identified'): Int64Index([1135], dtype='int64'),
#  ('First Foundation Inc.',
#   'Finance',
#   'No Industry Identified'): Int64Index([1136], dtype='int64'),
#  ('First Guaranty Bancshares, Inc.',
#   'Finance',
#   'No Industry Identified'): Int64Index([1137], dtype='int64'),
#  ('First Hawaiian, Inc.',
#   'Finance',
#   'No Industry Identified'): Int64Index([1138], dtype='int64'),
#  ('First Internet Bancorp',
#   'Finance',
#   'No Industry Identified'): Int64Index([1139, 1140], dtype='int64'),
#  ('First Interstate BancSystem, Inc.',
#   'Finance',
#   'No Industry Identified'): Int64Index([1141], dtype='int64'),
#  ('First Merchants Corporation',
#   'Finance',
#   'No Industry Identified'): Int64Index([1142], dtype='int64'),
#  ('First Mid Bancshares, Inc.',
#   'Finance',
#   'No Industry Identified'): Int64Index([1143], dtype='int64'),
#  ('First Midwest Bancorp, Inc.',
#   'Finance',
#   'No Industry Identified'): Int64Index([1144], dtype='int64'),
#  ('First National Corporation',
#   'Finance',
#   'No Industry Identified'): Int64Index([1145], dtype='int64'),
#  ('First Northwest Bancorp',
#   'Finance',
#   'No Industry Identified'): Int64Index([1146], dtype='int64'),
#  ('First Savings Financial Group, Inc.',
#   'Finance',
#   'No Industry Identified'): Int64Index([1147], dtype='int64'),
#  ('First Solar, Inc.',
#   'Technology',
#   'No Industry Identified'): Int64Index([1148], dtype='int64'),
#  ('First Trust Alternative Absolute Return Strategy ETF',
#   nan,
#   'No Industry Identified'): Int64Index([1149], dtype='int64'),
#  ('First Trust Asia Pacific Ex-Japan AlphaDEX Fund',
#   nan,
#   'No Industry Identified'): Int64Index([1150], dtype='int64'),
#  ('First Trust BICK Index Fund',
#   nan,
#   'No Industry Identified'): Int64Index([1151], dtype='int64'),
#  ('First Trust Brazil AlphaDEX Fund',
#   nan,
#   'No Industry Identified'): Int64Index([1152], dtype='int64'),
#  ('First Trust BuyWrite Income ETF',
#   nan,
#   'No Industry Identified'): Int64Index([1153], dtype='int64'),
#  ('First Trust California Municipal High income ETF',
#   nan,
#   'No Industry Identified'): Int64Index([1154], dtype='int64'),
#  ...}

# %%
# Getting list of 100 industries from 10 sectors. 
import requests
import pandas as pd
import numpy as np
import sys
import json
df = pd.DataFrame()

def get_avg_sector_rates():
    cols_to_use = [0,1,2,3,4,5,6,7]
    csv_file_path = "../../assets/companylist.csv"
    df = pd.read_csv(csv_file_path, 
        usecols= cols_to_use,
        encoding='utf-8'
        )
    df['IPOyear'] = df['IPOyear'].astype(str)
    df['IPOyear'] = df['IPOyear'].str.strip('.0')
    df = df.rename(index=str, columns = {"Symbol": "SYM", "Name": "CO.", "LastSale": "LP", "MarketCap": "MRKCAP", "IPOyear": "YR", "Sector": "SEC", "industry": "IND", "Summary Quote": "SUMQTE"})
    df['SYM'] = df['SYM'].str.strip()
    df['SEC'] = df['SEC'].str.strip()
    df['SEC_CONV'] = np.where(df['SEC']=="Consumer Durables", 'Consumer Industry', df['SEC'])
    df['SEC_CONV'] = np.where(df['SEC']=="Consumer Non-Durables", 'Consumer Industry', df['SEC'])
    df['SEC_CONV'] = np.where(df['SEC']=='Consumer Services', 'Consumer Industry', df['SEC'])
    df["SEC"] = df["SEC"].replace("Empty", "No Industry Identified")
    df["SEC_CONV"] = df["SEC_CONV"].replace("Empty", "No Industry Identified")
    df["SEC_CONV"] = df["SEC_CONV"].replace("Consumer Durables", "Consumer Industry")
    df["SEC_CONV"] = df["SEC_CONV"].replace("Consumer Non-Durables", "Consumer Industry")
    df["SEC_CONV"] = df["SEC_CONV"].replace("Technology", "Technology/Energy")
    df["SEC_CONV"] = df["SEC_CONV"].replace("Energy", "Technology/Energy")
    df = df.groupby('SEC_CONV').head(100)
    df = df.iloc[:, [8,3]]
    df['MRKCAP'] = df['MRKCAP'].str.replace('$', '')
    df['MRKCAP'] = df['MRKCAP'].str.replace(',', '')
    df['MRKCAP'] = df['MRKCAP'].str.replace('M', ' M')
    df['MRKCAP'] = df['MRKCAP'].str.replace('B', ' B')
    df['SEC_CONV'] = df['SEC_CONV'].fillna(value='No Industry Identified')
    df['MRKCAP'] = df['MRKCAP'].fillna(value='0 D')
    df.dropna(inplace = True)
    df[['MRKCAP_AMT','MRKCAP_TYPE']] = df.MRKCAP.str.split(" ",expand=True,)
    millions = df['MRKCAP_AMT'].str.replace('.', '').fillna(value='0').astype(int).multiply(other = 100, fill_value = 5)
    billions = df['MRKCAP_AMT'].str.replace('.', '').fillna(value='0').astype(int).multiply(other = 1000000, fill_value = 5)
    df.loc[df['MRKCAP_TYPE'] == 'M', 'Conversion'] = millions
    df.loc[df['MRKCAP_TYPE'] == 'B', 'Conversion'] = billions
    df.loc[df['MRKCAP_TYPE'] == 'D', 'Conversion'] = 0
    df.loc[df['MRKCAP_TYPE'] == 'None', 'Conversion'] = df['MRKCAP_AMT'].fillna(value='0')
    df['Conversion'] = df['Conversion'].fillna(value='0')
    df['Conversion'] = df['Conversion'].astype(int)
    print(df.dtypes)
    print(sys.maxsize)
    group_sectors = df.groupby(['SEC_CONV','Conversion'])
    res = df.groupby(['SEC_CONV'])['Conversion'].mean().reset_index()
#     print(res)
    res = res.to_json(orient='columns')
    res = json.dumps(res)
    res = res.replace('\\','')
    res = res.replace('"{','{')
    res = res.replace('}"','}')
#   res.to_csv(r'c:/development/python\mrkcap.csv')
    return res
get_avg_sector_rates()
# Out:
# SEC_CONV       object
# MRKCAP         object
# MRKCAP_AMT     object
# MRKCAP_TYPE    object
# Conversion      int32
# dtype: object
# 9223372036854775807
# '{"SEC_CONV":{"0":"Basic Industries","1":"Capital Goods","2":"Consumer Industry","3":"Finance","4":"Health Care","5":"Miscellaneous","6":"No Industry Identified","7":"Public Utilities","8":"Technology/Energy","9":"Transportation"},"Conversion":{"0":75113514.4736842066,"1":91961525.0400000066,"2":80414268.9599999934,"3":56359050.0,"4":61028234.1599999964,"5":61347932.3298969045,"6":31625552.0,"7":27974124.8615384623,"8":72443885.2399999946,"9":258053276.8571428657}}'

# %%
#API Data Pull
import pandas as pd
import requests
symbol = "YI"
def get_stock_data_from_alphavantage_by_symbol(symbol):
    # https://www.alphavantage.co/query?function=TIME_SERIES_DAILY&symbol=MSFT&outputsize=full&apikey=
    Alpha_Advantage_API = "https://www.alphavantage.co/query?function=SYMBOL_SEARCH&keywords=" + symbol + "&apikey=GJS1X1O8CLA8KA4H"
    resp = requests.get(Alpha_Advantage_API)
    if resp.status_code == 200:
        print(resp.status_code)
        data = resp.json()
#       print(data)
        data = data['bestMatches']
        df2 = pd.DataFrame.from_dict(data, orient='columns')
        df2.columns = ['SYM', 'CO.', 'Type', 'Country', 'LP-Time', 'LP-End-Time', 'UTC-Type', 'Dollar-Type', 'Last-List-Price']
        df2['SYM'] = df2['SYM'].str.strip()
        df2.loc[df2['SYM'] == str(symbol)]
        return df2
    else:
        print("API did not pull any data from alphavantage")
# Executes the function
get_stock_data_from_alphavantage_by_symbol(symbol)
# Out:
# 200
#      SYM                                          CO.    Type        Country  \
# 0     YI                                     111 Inc.  Equity  United States
# 1   YINN     Direxion Daily FTSE China Bull 3X Shares     ETF  United States
# 2    YRD                                Yirendai Ltd.  Equity  United States
# 3    YYY                  YieldShares High Income ETF     ETF  United States
# 4  BOSQF                       The Yield Growth Corp.  Equity  United States
# 5   YTEN                      Yield10 Bioscience Inc.  Equity  United States
# 6  YGEHY  Yingli Green Energy Holding Company Limited  Equity  United States
# 7    YIN          Yintech Investment Holdings Limited  Equity  United States
# 8   YIPI                                   Yippy Inc.  Equity  United States
#
#   LP-Time LP-End-Time UTC-Type Dollar-Type Last-List-Price
# 0   09:30       16:00   UTC-04         USD          1.0000
# 1   09:30       16:00   UTC-04         USD          0.8000
# 2   09:30       16:00   UTC-04         USD          0.6667
# 3   09:30       16:00   UTC-04         USD          0.6667
# 4   09:30       16:00   UTC-04         USD          0.4000
# 5   09:30       16:00   UTC-04         USD          0.4000
# 6   09:30       16:00   UTC-04         USD          0.3333
# 7   09:30       16:00   UTC-04         USD          0.2857
# 8   09:30       16:00   UTC-04         USD          0.1667

# %%
# Getting the 5 top companies of each sector with Market Cap
import requests
import pandas as pd
import numpy as np
import sys
import json
df = pd.DataFrame()

def get_top_companies_market_cap():
    cols_to_use = [0,1,2,3,4,5,6,7]
    csv_file_path = "../../assets/companylist.csv"
    df = pd.read_csv(csv_file_path, 
        usecols= cols_to_use,
        encoding='utf-8'
        )
    df['IPOyear'] = df['IPOyear'].astype(str)
    df['IPOyear'] = df['IPOyear'].str.strip('.0')
    df = df.rename(index=str, columns = {"Symbol": "SYM", "Name": "CO.", "LastSale": "LP", "MarketCap": "MRKCAP", "IPOyear": "YR", "Sector": "SEC", "industry": "IND", "Summary Quote": "SUMQTE"})
    df['SYM'] = df['SYM'].str.strip()
    df['SEC'] = df['SEC'].str.strip()
    df['SEC_CONV'] = np.where(df['SEC']=="Consumer Durables", 'Consumer Industry', df['SEC'])
    df['SEC_CONV'] = np.where(df['SEC']=="Consumer Non-Durables", 'Consumer Industry', df['SEC'])
    df['SEC_CONV'] = np.where(df['SEC']=='Consumer Services', 'Consumer Industry', df['SEC'])
    df["SEC"] = df["SEC"].replace("Empty", "No Industry Identified")
    df["SEC_CONV"] = df["SEC_CONV"].replace("Empty", "No Industry Identified")
    df["SEC_CONV"] = df["SEC_CONV"].replace("Consumer Durables", "Consumer Industry")
    df["SEC_CONV"] = df["SEC_CONV"].replace("Consumer Non-Durables", "Consumer Industry")
    df["SEC_CONV"] = df["SEC_CONV"].replace("Technology", "Technology/Energy")
    df["SEC_CONV"] = df["SEC_CONV"].replace("Energy", "Technology/Energy")
    df = df.groupby('SEC_CONV').head(100)
#     df = df.iloc[:, [8,3]]
    df['MRKCAP'] = df['MRKCAP'].str.replace('$', '')
    df['MRKCAP'] = df['MRKCAP'].str.replace(',', '')
    df['MRKCAP'] = df['MRKCAP'].str.replace('M', ' M')
    df['MRKCAP'] = df['MRKCAP'].str.replace('B', ' B')
    df['SEC_CONV'] = df['SEC_CONV'].fillna(value='No Industry Identified')
    df['MRKCAP'] = df['MRKCAP'].fillna(value='0 D')
    df.dropna(inplace = True)
    df[['MRKCAP_AMT','MRKCAP_TYPE']] = df.MRKCAP.str.split(" ",expand=True,)
    millions = df['MRKCAP_AMT'].str.replace('.', '').fillna(value='0').astype(int).multiply(other = 100, fill_value = 5)
    billions = df['MRKCAP_AMT'].str.replace('.', '').fillna(value='0').astype(int).multiply(other = 1000000, fill_value = 5)
    df.loc[df['MRKCAP_TYPE'] == 'M', 'Conversion'] = millions
    df.loc[df['MRKCAP_TYPE'] == 'B', 'Conversion'] = billions
    df.loc[df['MRKCAP_TYPE'] == 'D', 'Conversion'] = 0
    df.loc[df['MRKCAP_TYPE'] == 'None', 'Conversion'] = df['MRKCAP_AMT'].fillna(value='0')
    df['Conversion'] = df['Conversion'].fillna(value='0')
    df['Conversion'] = df['Conversion'].astype(int)
#     print(df.dtypes)
#     print(sys.maxsize)
#     group_sectors = df.groupby(['SEC_CONV','Conversion'])
#     res = df.groupby(['SEC_CONV'])['Conversion'].mean().reset_index()
    
#     print(res)
#     res = res.to_json(orient='columns')
#     res = json.dumps(res)
#     res = res.replace('\\','')
#     res = res.replace('"{','{')
#     res = res.replace('}"','}')
#   res.to_csv(r'c:/development/python\mrkcap.csv')
    return df
get_top_companies_market_cap()
# Out:
#         SYM                                         CO.        LP    MRKCAP  \
# 0        YI                                   111, Inc.    8.5600     699 M
# 1       PIH      1347 Property Insurance Holdings, Inc.    5.7400   34.51 M
# 2     PIHPP      1347 Property Insurance Holdings, Inc.   25.2499   17.67 M
# 3      TURN                    180 Degree Capital Corp.    1.9598   60.99 M
# 4      FLWS                     1-800 FLOWERS.COM, Inc.   18.4600    1.19 B
# 5      BCOW             1895 Bancorp of Wisconsin, Inc.    9.3727   45.71 M
# 6      FCCY               1st Constitution Bancorp (NJ)   18.7500  161.77 M
# 7      SRCE                      1st Source Corporation   45.4700    1.17 B
# 8      VNET                        21Vianet Group, Inc.    7.5500  848.56 M
# 9      TWOU                                    2U, Inc.   39.5200    2.49 B
# 10     QFIN                           360 Finance, Inc.   16.2700    2.34 B
# 11     JOBS                                 51job, Inc.   68.1100    4.26 B
# 12      JFK             8i Enterprises Acquisition Corp    9.8600    56.7 M
# 13    JFKKR             8i Enterprises Acquisition Corp    0.1994       0 D
# 14    JFKKU             8i Enterprises Acquisition Corp   10.1700   50.85 M
# 15    JFKKW             8i Enterprises Acquisition Corp    0.1400   805000
# 16     EGHT                                     8x8 Inc   23.7800    2.29 B
# 17     AAON                                  AAON, Inc.   46.6500    2.43 B
# 18     ABEO                    Abeona Therapeutics Inc.    6.5500  322.01 M
# 19    ABEOW                    Abeona Therapeutics Inc.    2.2000       0 D
# 20     ABIL                                Ability Inc.    1.2550   10.09 M
# 21     ABMD                               ABIOMED, Inc.  270.3900    12.2 B
# 22     AXAS               Abraxas Petroleum Corporation    1.0500  176.79 M
# 23     ACIU                                AC Immune SA    5.0300  339.84 M
# 24     ACIA                 Acacia Communications, Inc.   47.3100    1.92 B
# 25     ACTG                 Acacia Research Corporation    3.1300   156.7 M
# 26     ACHC             Acadia Healthcare Company, Inc.   32.7100    2.89 B
# 27     ACAD                 ACADIA Pharmaceuticals Inc.   25.9600    3.74 B
# 28     ACAM           Acamar Partners Acquisition Corp.    9.7500  372.42 M
# 29    ACAMU           Acamar Partners Acquisition Corp.   10.0000       0 D
# ...     ...                                         ...       ...       ...
# 3128   TMUS                           T-Mobile US, Inc.   77.2700   66.01 B
# 3132   TOPS                              TOP Ships Inc.    0.5950   14.85 M
# 3134   TRMD                                    TORM plc    9.0000   665.1 M
# 3189     TC                             TuanChe Limited    5.6000  405.01 M
# 3219   ULBI                       Ultralife Corporation    7.7700  122.27 M
# 3230    UAL           United Continental Holdings, Inc.   80.7900   21.26 B
# 3236   USLM         United States Lime & Minerals, Inc.   81.9300  459.79 M
# 3244   UFPI             Universal Forest Products, Inc.   34.1600     2.1 B
# 3245    ULH          Universal Logistics Holdings, Inc.   20.0500  578.22 M
# 3246   USAP  Universal Stainless & Alloy Products, Inc.   12.9600  113.69 M
# 3255    MYT                             Urban Tea, Inc.    1.1300   26.14 M
# 3258   ECOL                            US Ecology, Inc.   58.8100     1.3 B
# 3259   USAT                      USA Technologies, Inc.    7.1300  427.81 M
# 3260  USATP                      USA Technologies, Inc.   22.5000   10.01 M
# 3261   USAK                             USA Truck, Inc.   12.3500  105.45 M
# 3264   UXIN                                Uxin Limited    2.3300  712.97 M
# 3309   VEON                                   VEON Ltd.    2.3800    4.16 B
# 3372   VVPR                 VivoPower International PLC    1.1100   15.05 M
# 3374    VOD                          Vodafone Group Plc   15.9900   42.73 B
# 3381   WTRH                         Waitr Holdings Inc.    7.1200  545.93 M
# 3391   WDFC                               WD-40 Company  160.9600    2.22 B
# 3400   WERN                    Werner Enterprises, Inc.   29.3700    2.05 B
# 3404   WSTL                  Westell Technologies, Inc.    2.1800   33.54 M
# 3410    WWR                   Westwater Resources, Inc.    5.9600    8.91 M
# 3455   XELB                            Xcel Brands, Inc    1.3000   24.59 M
# 3456    XEL                            Xcel Energy Inc.   58.9900   30.36 B
# 3472   YTEN                    Yield10 Bioscience, Inc.    0.8844   11.05 M
# 3477   YRCW                         YRC Worldwide, Inc.    4.7300  163.53 M
# 3485      Z                          Zillow Group, Inc.   41.8600    5.89 B
# 3486     ZG                          Zillow Group, Inc.   41.3600    8.49 B
#
#         YR                SEC  \
# 0     2018        Health Care
# 1     2014            Finance
# 2      nan            Finance
# 3      nan            Finance
# 4     1999  Consumer Services
# 5     2019            Finance
# 6      nan            Finance
# 7      nan            Finance
# 8     2011         Technology
# 9     2014         Technology
# 10    2018            Finance
# 11    2004         Technology
# 12    2019            Finance
# 13    2019            Finance
# 14    2019            Finance
# 15    2019            Finance
# 16     nan         Technology
# 17     nan      Capital Goods
# 18     nan        Health Care
# 19     nan        Health Care
# 20    2014      Capital Goods
# 21     nan        Health Care
# 22     nan             Energy
# 23    2016        Health Care
# 24    2016         Technology
# 25     nan      Miscellaneous
# 26     nan        Health Care
# 27    1985        Health Care
# 28    2019            Finance
# 29    2019            Finance
# ...    ...                ...
# 3128   nan   Public Utilities
# 3132   nan     Transportation
# 3134   nan     Transportation
# 3189  2018      Miscellaneous
# 3219  1992      Miscellaneous
# 3230   nan     Transportation
# 3236   nan   Basic Industries
# 3244  1993   Basic Industries
# 3245   nan     Transportation
# 3246  1994   Basic Industries
# 3255   nan   Basic Industries
# 3258   nan   Public Utilities
# 3259   nan      Miscellaneous
# 3260   nan      Miscellaneous
# 3261  1992     Transportation
# 3264  2018      Miscellaneous
# 3309   nan   Public Utilities
# 3372   nan   Public Utilities
# 3374   nan   Public Utilities
# 3381  2016      Miscellaneous
# 3391  1973   Basic Industries
# 3400  1986     Transportation
# 3404  1995   Public Utilities
# 3410   nan   Basic Industries
# 3455   nan      Miscellaneous
# 3456   nan   Public Utilities
# 3472   nan   Basic Industries
# 3477   nan     Transportation
# 3485   nan      Miscellaneous
# 3486  2011      Miscellaneous
#
#                                                     IND  \
# 0                              Medical/Nursing Services
# 1                            Property-Casualty Insurers
# 2                            Property-Casualty Insurers
# 3                            Finance/Investors Services
# 4                                Other Specialty Stores
# 5                                                 Banks
# 6                                  Savings Institutions
# 7                                           Major Banks
# 8       Computer Software: Programming, Data Processing
# 9               Computer Software: Prepackaged Software
# 10                           Finance: Consumer Services
# 11                      Diversified Commercial Services
# 12                                    Business Services
# 13                                    Business Services
# 14                                    Business Services
# 15                                    Business Services
# 16                                         EDP Services
# 17                      Industrial Machinery/Components
# 18                                Major Pharmaceuticals
# 19                                Major Pharmaceuticals
# 20                         Telecommunications Equipment
# 21                           Medical/Dental Instruments
# 22                                 Oil & Gas Production
# 23                                Major Pharmaceuticals
# 24                                       Semiconductors
# 25                               Multi-Sector Companies
# 26                                 Medical Specialities
# 27                                Major Pharmaceuticals
# 28                                    Business Services
# 29                                    Business Services
# ...                                                 ...
# 3128                       Telecommunications Equipment
# 3132                              Marine Transportation
# 3134                              Marine Transportation
# 3189                                  Business Services
# 3219                    Industrial Machinery/Components
# 3230                      Air Freight/Delivery Services
# 3236  Mining & Quarrying of Nonmetallic Minerals (No...
# 3244                                    Forest Products
# 3245                  Trucking Freight/Courier Services
# 3246                                     Steel/Iron Ore
# 3255                                    Major Chemicals
# 3258                             Environmental Services
# 3259                 Office Equipment/Supplies/Services
# 3260                 Office Equipment/Supplies/Services
# 3261                  Trucking Freight/Courier Services
# 3264                                  Business Services
# 3309                       Telecommunications Equipment
# 3372                                   Power Generation
# 3374                       Telecommunications Equipment
# 3381                                  Business Services
# 3391                                    Major Chemicals
# 3400                  Trucking Freight/Courier Services
# 3404                       Telecommunications Equipment
# 3410                                    Precious Metals
# 3455                             Multi-Sector Companies
# 3456                                   Power Generation
# 3472                               Containers/Packaging
# 3477                  Trucking Freight/Courier Services
# 3485                                  Business Services
# 3486                                  Business Services
#
#                                    SUMQTE           SEC_CONV MRKCAP_AMT  \
# 0        https://www.nasdaq.com/symbol/yi        Health Care        699
# 1       https://www.nasdaq.com/symbol/pih            Finance      34.51
# 2     https://www.nasdaq.com/symbol/pihpp            Finance      17.67
# 3      https://www.nasdaq.com/symbol/turn            Finance      60.99
# 4      https://www.nasdaq.com/symbol/flws  Consumer Industry       1.19
# 5      https://www.nasdaq.com/symbol/bcow            Finance      45.71
# 6      https://www.nasdaq.com/symbol/fccy            Finance     161.77
# 7      https://www.nasdaq.com/symbol/srce            Finance       1.17
# 8      https://www.nasdaq.com/symbol/vnet  Technology/Energy     848.56
# 9      https://www.nasdaq.com/symbol/twou  Technology/Energy       2.49
# 10     https://www.nasdaq.com/symbol/qfin            Finance       2.34
# 11     https://www.nasdaq.com/symbol/jobs  Technology/Energy       4.26
# 12      https://www.nasdaq.com/symbol/jfk            Finance       56.7
# 13    https://www.nasdaq.com/symbol/jfkkr            Finance          0
# 14    https://www.nasdaq.com/symbol/jfkku            Finance      50.85
# 15    https://www.nasdaq.com/symbol/jfkkw            Finance     805000
# 16     https://www.nasdaq.com/symbol/eght  Technology/Energy       2.29
# 17     https://www.nasdaq.com/symbol/aaon      Capital Goods       2.43
# 18     https://www.nasdaq.com/symbol/abeo        Health Care     322.01
# 19    https://www.nasdaq.com/symbol/abeow        Health Care          0
# 20     https://www.nasdaq.com/symbol/abil      Capital Goods      10.09
# 21     https://www.nasdaq.com/symbol/abmd        Health Care       12.2
# 22     https://www.nasdaq.com/symbol/axas  Technology/Energy     176.79
# 23     https://www.nasdaq.com/symbol/aciu        Health Care     339.84
# 24     https://www.nasdaq.com/symbol/acia  Technology/Energy       1.92
# 25     https://www.nasdaq.com/symbol/actg      Miscellaneous      156.7
# 26     https://www.nasdaq.com/symbol/achc        Health Care       2.89
# 27     https://www.nasdaq.com/symbol/acad        Health Care       3.74
# 28     https://www.nasdaq.com/symbol/acam            Finance     372.42
# 29    https://www.nasdaq.com/symbol/acamu            Finance          0
# ...                                   ...                ...        ...
# 3128   https://www.nasdaq.com/symbol/tmus   Public Utilities      66.01
# 3132   https://www.nasdaq.com/symbol/tops     Transportation      14.85
# 3134   https://www.nasdaq.com/symbol/trmd     Transportation      665.1
# 3189     https://www.nasdaq.com/symbol/tc      Miscellaneous     405.01
# 3219   https://www.nasdaq.com/symbol/ulbi      Miscellaneous     122.27
# 3230    https://www.nasdaq.com/symbol/ual     Transportation      21.26
# 3236   https://www.nasdaq.com/symbol/uslm   Basic Industries     459.79
# 3244   https://www.nasdaq.com/symbol/ufpi   Basic Industries        2.1
# 3245    https://www.nasdaq.com/symbol/ulh     Transportation     578.22
# 3246   https://www.nasdaq.com/symbol/usap   Basic Industries     113.69
# 3255    https://www.nasdaq.com/symbol/myt   Basic Industries      26.14
# 3258   https://www.nasdaq.com/symbol/ecol   Public Utilities        1.3
# 3259   https://www.nasdaq.com/symbol/usat      Miscellaneous     427.81
# 3260  https://www.nasdaq.com/symbol/usatp      Miscellaneous      10.01
# 3261   https://www.nasdaq.com/symbol/usak     Transportation     105.45
# 3264   https://www.nasdaq.com/symbol/uxin      Miscellaneous     712.97
# 3309   https://www.nasdaq.com/symbol/veon   Public Utilities       4.16
# 3372   https://www.nasdaq.com/symbol/vvpr   Public Utilities      15.05
# 3374    https://www.nasdaq.com/symbol/vod   Public Utilities      42.73
# 3381   https://www.nasdaq.com/symbol/wtrh      Miscellaneous     545.93
# 3391   https://www.nasdaq.com/symbol/wdfc   Basic Industries       2.22
# 3400   https://www.nasdaq.com/symbol/wern     Transportation       2.05
# 3404   https://www.nasdaq.com/symbol/wstl   Public Utilities      33.54
# 3410    https://www.nasdaq.com/symbol/wwr   Basic Industries       8.91
# 3455   https://www.nasdaq.com/symbol/xelb      Miscellaneous      24.59
# 3456    https://www.nasdaq.com/symbol/xel   Public Utilities      30.36
# 3472   https://www.nasdaq.com/symbol/yten   Basic Industries      11.05
# 3477   https://www.nasdaq.com/symbol/yrcw     Transportation     163.53
# 3485      https://www.nasdaq.com/symbol/z      Miscellaneous       5.89
# 3486     https://www.nasdaq.com/symbol/zg      Miscellaneous       8.49
#
#      MRKCAP_TYPE  Conversion
# 0              M       69900
# 1              M      345100
# 2              M      176700
# 3              M      609900
# 4              B   119000000
# 5              M      457100
# 6              M     1617700
# 7              B   117000000
# 8              M     8485600
# 9              B   249000000
# 10             B   234000000
# 11             B   426000000
# 12             M       56700
# 13             D           0
# 14             M      508500
# 15                         0
# 16             B   229000000
# 17             B   243000000
# 18             M     3220100
# 19             D           0
# 20             M      100900
# 21             B   122000000
# 22             M     1767900
# 23             M     3398400
# 24             B   192000000
# 25             M      156700
# 26             B   289000000
# 27             B   374000000
# 28             M     3724200
# 29             D           0
# ...          ...         ...
# 3128           B -1988934592
# 3132           M      148500
# 3134           M      665100
# 3189           M     4050100
# 3219           M     1222700
# 3230           B  2126000000
# 3236           M     4597900
# 3244           B    21000000
# 3245           M     5782200
# 3246           M     1136900
# 3255           M      261400
# 3258           B    13000000
# 3259           M     4278100
# 3260           M      100100
# 3261           M     1054500
# 3264           M     7129700
# 3309           B   416000000
# 3372           M      150500
# 3374           B   -21967296
# 3381           M     5459300
# 3391           B   222000000
# 3400           B   205000000
# 3404           M      335400
# 3410           M       89100
# 3455           M      245900
# 3456           B -1258967296
# 3472           M      110500
# 3477           M     1635300
# 3485           B   589000000
# 3486           B   849000000
#
# [792 rows x 12 columns]

# %%
#Merging data that is found within the Second Dataframe from the API
def merge_company_data_for_single_api(sym1, sym2):
#     sym1 = get_stock_data_from_alphavantage_by_symbol()
#     sym2 = get_company_data_from_csv()
    return sym1.merge(sym2)
# Out:
# 200
#    SYM                                  CO.    Type        Country LP-Time  \
# 0  YIN  Yintech Investment Holdings Limited  Equity  United States   09:30
#
#   LP-End-Time UTC-Type Dollar-Type Last-List-Price    LP    MRKCAP    YR  \
# 0       16:00   UTC-04         USD          0.4000  4.95  $353.66M  2016
#
#        SEC                                 IND  \
# 0  Finance  Investment Bankers/Brokers/Service
#
#                               SUMQTE
# 0  https://www.nasdaq.com/symbol/yin

# %%
#Info from API
import pandas as pd
import requests
def get_sector_stats():
    Alpha_Advantage_API_Sector = "https://www.alphavantage.co/query?function=SECTOR&apikey=GJS1X1O8CLA8KA4H"
    resp = requests.get(Alpha_Advantage_API_Sector)
    if resp.status_code == 200:
        print(resp.status_code)
        data = resp.json()
        df3 = pd.DataFrame.from_dict(data, orient='columns')
        df3.columns = ['SEC', 'Real_Time', '1_Day_Performance', '5_Day_Performance', '1_Month_Performance', '3_Month_Performance', 'YTD_Performance', '1_Year_Performance', '3_Year_Performance', '5_Year_Performance', '10_Year_Performance']
#         df3['SEC'] = df3['SEC'].str.strip()
#         df2.loc[df2['SYM'] == str(symbol)]
        df3 = df3['SEC']
        df3 = df3.replace('NaN', '')
        return df3
    else:
        print("API did not pull any data from alphavantage")
get_sector_stats()
# Out:
# 200
# Communication Services                                              NaN
# Consumer Discretionary                                              NaN
# Consumer Staples                                                    NaN
# Energy                                                              NaN
# Financials                                                          NaN
# Health Care                                                         NaN
# Industrials                                                         NaN
# Information               US Sector Performance (realtime & historical)
# Information Technology                                              NaN
# Last Refreshed                                   04:20 PM ET 05/23/2019
# Materials                                                           NaN
# Real Estate                                                         NaN
# Utilities                                                           NaN
# Name: SEC, dtype: object

# %%
#Articles via API
import pandas as pd
import requests
def get_stock_news():
    stock_news_api = "https://stocknewsapi.com/api/v1?tickers=YI&items=50&type=article&token=qqygybi5zike7wfmu21lawdnfndqhhi53ndszk83"
    resp = requests.get(stock_news_api)
    if resp.status_code == 200:
        print(resp.status_code)
        data = resp.json()
        data = data['data']
        df4 = pd.DataFrame.from_dict(data, orient='columns')
        df4.columns = ['DATE', 'IMG_URL', 'NEWS_URL', 'Sentiment', 'Source_Name', 'Tags', 'Text', 'SYM', 'Title', 'Type']
        return df4
    else:
        print("API did not pull any data from alphavantage")
get_stock_news()
# Out:
# 200
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-362-0461136e90df> in <module>
#      14     else:
#      15         print("API did not pull any data from alphavantage")
# ---> 16 get_stock_news()
#
# <ipython-input-362-0461136e90df> in get_stock_news()
#      10         data = data['data']
#      11         df4 = pd.DataFrame.from_dict(data, orient='columns')
# ---> 12         df4.columns = ['DATE', 'IMG_URL', 'NEWS_URL', 'Sentiment', 'Source_Name', 'Tags', 'Text', 'SYM', 'Title', 'Type']
#      13         return df4
#      14     else:
#
# c:\users\ksummersill\appdata\local\programs\python\python37\lib\site-packages\pandas\core\generic.py in __setattr__(self, name, value)
#    5078         try:
#    5079             object.__getattribute__(self, name)
# -> 5080             return object.__setattr__(self, name, value)
#    5081         except AttributeError:
#    5082             pass
#
# pandas\_libs\properties.pyx in pandas._libs.properties.AxisProperty.__set__()
#
# c:\users\ksummersill\appdata\local\programs\python\python37\lib\site-packages\pandas\core\generic.py in _set_axis(self, axis, labels)
#     636
#     637     def _set_axis(self, axis, labels):
# --> 638         self._data.set_axis(axis, labels)
#     639         self._clear_item_cache()
#     640
#
# c:\users\ksummersill\appdata\local\programs\python\python37\lib\site-packages\pandas\core\internals\managers.py in set_axis(self, axis, new_labels)
#     153             raise ValueError(
#     154                 'Length mismatch: Expected axis has {old} elements, new '
# --> 155                 'values have {new} elements'.format(old=old_len, new=new_len))
#     156
#     157         self.axes[axis] = new_labels
#
# ValueError: Length mismatch: Expected axis has 0 elements, new values have 10 elements

# %%
#Web Scrap
import pandas as pd
import requests
from bs4 import BeautifulSoup
symbols = ['yi','bhf']
companyimages = []
nasdaq_website = "https://www.nasdaq.com/symbol/fgp"
page = requests.get(nasdaq_website)
soup = BeautifulSoup(page.text, 'html.parser')
review_text_elem = soup.find_all(class_='quote-symbol-icon')

for item in review_text_elem:
    companyimages.append(item)

companyimages
# review_text_elem
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-2-d636993c4000> in <module>
#       1 #Web Scrap
#       2 import pandas as pd
# ----> 3 import requests
#       4 from bs4 import BeautifulSoup
#       5 symbols = ['yi','bhf']
#
# ModuleNotFoundError: No module named 'requests'

# %%
#API Data Pull
import pandas as pd
import requests
from IPython.core import display as ICD
cols_to_use = [0,1,2,3,4,5,6,7]
csv_file_path = r"../../assets/companylist.csv"
df = pd.read_csv(csv_file_path, 
                 usecols= cols_to_use,
                 encoding='utf-8'
                )
df['IPOyear'] = df['IPOyear'].astype(str)
df['IPOyear'] = df['IPOyear'].str.strip('.0')
df = df.rename(index=str, columns = {"Symbol": "SYM", "Name": "CO.", "LastSale": "LP", "MarketCap": "MRKCAP", "IPOyear": "YR", "Sector": "SEC", "industry": "IND", "Summary Quote": "SUMQTE"})
arraySymbols = []
for x in range (0, len(df['SYM'])):
    arraySymbols.append(df.iloc[x]['SYM'])
    
#print (len(df['SYM']))
#print (arraySymbols)
#print (len(arraySymbols))
def combine_csv_api (symbol):
    Alpha_Advantage_API = "https://www.alphavantage.co/query?function=SYMBOL_SEARCH&keywords=" + symbol + "&apikey=GJS1X1O8CLA8KA4H"
    resp = requests.get(Alpha_Advantage_API)
    
    if resp.status_code == 200:
        data = resp.json()
        print (data)
        data = data['bestMatches']
        
        df2 = pd.DataFrame.from_dict(data, orient='columns')
        df2.columns = ['SYM', 'CO.', 'Type', 'Country', 'LP-Time', 'LP-End-Time', 'UTC-Type', 'Dollar-Type', 'Last-List-Price']
        df2['SYM'] = df2['SYM'].str.strip()
        
        df3 = pd.merge(df.loc[df["SYM"] == str(symbol)], df2.loc[df2['SYM'] == str(symbol)], on="SYM")
        
        del df3['CO._y']
        
        df3.columns = ['SYM','CO.','LP','MRKCAP','YR','SEC','IND','SUMQTE', 'Type','Country','LP-Time', 'LP-End-Time', 'UTC-Type', 'Dollar-Type', 'Last-List-Price']
                
        return df3 #ICD.display(df3)
    
        #return (df.loc[df["SYM"] == "YI"])
    
    else:
        print("API did not pull any data from alphavantage")
# Executes the function    
for x in range (1, len(arraySymbols)):
    if x == 1:
        df4 = combine_csv_api (arraySymbols[x-1])
        df5 = combine_csv_api (arraySymbols[x])
        
        dfFinal = df4.append(df5)
    else:
        df6 = combine_csv_api (arraySymbols[x])
        dfFinal = dfFinal.append(df6)
print (dfFinal)
# Out:
# {'bestMatches': [{'1. symbol': 'YI', '2. name': '111 Inc.', '3. type': 'Equity', '4. region': 'United States', '5. marketOpen': '09:30', '6. marketClose': '16:00', '7. timezone': 'UTC-04', '8. currency': 'USD', '9. matchScore': '1.0000'}, {'1. symbol': 'YINN', '2. name': 'Direxion Daily FTSE China Bull 3X Shares', '3. type': 'ETF', '4. region': 'United States', '5. marketOpen': '09:30', '6. marketClose': '16:00', '7. timezone': 'UTC-04', '8. currency': 'USD', '9. matchScore': '0.8000'}, {'1. symbol': 'YRD', '2. name': 'Yirendai Ltd.', '3. type': 'Equity', '4. region': 'United States', '5. marketOpen': '09:30', '6. marketClose': '16:00', '7. timezone': 'UTC-04', '8. currency': 'USD', '9. matchScore': '0.6667'}, {'1. symbol': 'YYY', '2. name': 'YieldShares High Income ETF', '3. type': 'ETF', '4. region': 'United States', '5. marketOpen': '09:30', '6. marketClose': '16:00', '7. timezone': 'UTC-04', '8. currency': 'USD', '9. matchScore': '0.6667'}, {'1. symbol': 'BOSQF', '2. name': 'The Yield Growth Corp.', '3. type': 'Equity', '4. region': 'United States', '5. marketOpen': '09:30', '6. marketClose': '16:00', '7. timezone': 'UTC-04', '8. currency': 'USD', '9. matchScore': '0.4000'}, {'1. symbol': 'YTEN', '2. name': 'Yield10 Bioscience Inc.', '3. type': 'Equity', '4. region': 'United States', '5. marketOpen': '09:30', '6. marketClose': '16:00', '7. timezone': 'UTC-04', '8. currency': 'USD', '9. matchScore': '0.4000'}, {'1. symbol': 'YGEHY', '2. name': 'Yingli Green Energy Holding Company Limited', '3. type': 'Equity', '4. region': 'United States', '5. marketOpen': '09:30', '6. marketClose': '16:00', '7. timezone': 'UTC-04', '8. currency': 'USD', '9. matchScore': '0.3333'}, {'1. symbol': 'YIN', '2. name': 'Yintech Investment Holdings Limited', '3. type': 'Equity', '4. region': 'United States', '5. marketOpen': '09:30', '6. marketClose': '16:00', '7. timezone': 'UTC-04', '8. currency': 'USD', '9. matchScore': '0.2857'}, {'1. symbol': 'YIPI', '2. name': 'Yippy Inc.', '3. type': 'Equity', '4. region': 'United States', '5. marketOpen': '09:30', '6. marketClose': '16:00', '7. timezone': 'UTC-04', '8. currency': 'USD', '9. matchScore': '0.1667'}]}
# {'bestMatches': [{'1. symbol': 'PIH', '2. name': '1347 Property Insurance Holdings Inc.', '3. type': 'Equity', '4. region': 'United States', '5. marketOpen': '09:30', '6. marketClose': '16:00', '7. timezone': 'UTC-04', '8. currency': 'USD', '9. matchScore': '1.0000'}, {'1. symbol': 'PIHPP', '2. name': '1347 Property Insurance Holdings Inc.', '3. type': 'Equity', '4. region': 'United States', '5. marketOpen': '09:30', '6. marketClose': '16:00', '7. timezone': 'UTC-04', '8. currency': 'USD', '9. matchScore': '0.8571'}, {'1. symbol': 'PIHLF', '2. name': 'Pihlajalinna Oyj', '3. type': 'Equity', '4. region': 'United States', '5. marketOpen': '09:30', '6. marketClose': '16:00', '7. timezone': 'UTC-04', '8. currency': 'USD', '9. matchScore': '0.7500'}, {'1. symbol': 'PIHN', '2. name': 'Polaris International Holdings Inc.', '3. type': 'Equity', '4. region': 'United States', '5. marketOpen': '09:30', '6. marketClose': '16:00', '7. timezone': 'UTC-04', '8. currency': 'USD', '9. matchScore': '0.7500'}, {'1. symbol': '38P.FRK', '2. name': 'Pihlajalinna Oyj', '3. type': 'Equity', '4. region': 'Frankfurt', '5. marketOpen': '08:00', '6. marketClose': '20:00', '7. timezone': 'UTC+02', '8. currency': 'EUR', '9. matchScore': '0.3333'}, {'1. symbol': '38P.MUN', '2. name': 'PIHLAJALINNA OY', '3. type': 'Equity', '4. region': 'Munich', '5. marketOpen': '08:00', '6. marketClose': '20:00', '7. timezone': 'UTC+02', '8. currency': 'EUR', '9. matchScore': '0.3333'}, {'1. symbol': '0R8H.LON', '2. name': 'Pihlajalinna Oyj', '3. type': 'Equity', '4. region': 'United Kingdom', '5. marketOpen': '08:00', '6. marketClose': '16:30', '7. timezone': 'UTC+01', '8. currency': 'GBP', '9. matchScore': '0.3158'}, {'1. symbol': '38P.BER', '2. name': 'PIHLAJALINNA OY', '3. type': 'Equity', '4. region': 'Berlin', '5. marketOpen': '08:00', '6. marketClose': '20:00', '7. timezone': 'UTC+02', '8. currency': 'EUR', '9. matchScore': '0.3158'}]}
# {'bestMatches': [{'1. symbol': 'PIHPP', '2. name': '1347 Property Insurance Holdings Inc.', '3. type': 'Equity', '4. region': 'United States', '5. marketOpen': '09:30', '6. marketClose': '16:00', '7. timezone': 'UTC-04', '8. currency': 'USD', '9. matchScore': '1.0000'}]}
# {'bestMatches': [{'1. symbol': 'TURN', '2. name': '180 Degree Capital Corp.', '3. type': 'Equity', '4. region': 'United States', '5. marketOpen': '09:30', '6. marketClose': '16:00', '7. timezone': 'UTC-04', '8. currency': 'USD', '9. matchScore': '1.0000'}, {'1. symbol': 'TPTX', '2. name': 'Turning Point Therapeutics Inc.', '3. type': 'Equity', '4. region': 'United States', '5. marketOpen': '09:30', '6. marketClose': '16:00', '7. timezone': 'UTC-04', '8. currency': 'USD', '9. matchScore': '0.6000'}, {'1. symbol': 'TPB', '2. name': 'Turning Point Brands Inc.', '3. type': 'Equity', '4. region': 'United States', '5. marketOpen': '09:30', '6. marketClose': '16:00', '7. timezone': 'UTC-04', '8. currency': 'USD', '9. matchScore': '0.4000'}, {'1. symbol': 'TVOG', '2. name': 'Turner Valley Oil & Gas Inc.', '3. type': 'Equity', '4. region': 'United States', '5. marketOpen': '09:30', '6. marketClose': '16:00', '7. timezone': 'UTC-04', '8. currency': 'USD', '9. matchScore': '0.4000'}, {'1. symbol': 'TKCI', '2. name': 'TurnKey Capital Inc.', '3. type': 'Equity', '4. region': 'United States', '5. marketOpen': '09:30', '6. marketClose': '16:00', '7. timezone': 'UTC-04', '8. currency': 'USD', '9. matchScore': '0.3200'}, {'1. symbol': 'ITRNAX', '2. name': 'Turnaround Strategy Portfolio 2', '3. type': 'Mutual Fund', '4. region': 'United States', '5. marketOpen': '09:30', '6. marketClose': '16:00', '7. timezone': 'UTC-04', '8. currency': 'USD', '9. matchScore': '0.2857'}, {'1. symbol': 'ITSPNX', '2. name': 'Turnaround Strategy Portfolio 2', '3. type': 'Mutual Fund', '4. region': 'United States', '5. marketOpen': '09:30', '6. marketClose': '16:00', '7. timezone': 'UTC-04', '8. currency': 'USD', '9. matchScore': '0.2500'}, {'1. symbol': 'TRA.AUS', '2. name': 'Turners Automotive Group Limited', '3. type': 'Equity', '4. region': 'Australia', '5. marketOpen': '10:00', '6. marketClose': '16:00', '7. timezone': 'UTC+12', '8. currency': 'AUD', '9. matchScore': '0.2500'}]}
# {'bestMatches': [{'1. symbol': 'FLWS', '2. name': '1-800-FLOWERS.COM Inc.', '3. type': 'Equity', '4. region': 'United States', '5. marketOpen': '09:30', '6. marketClose': '16:00', '7. timezone': 'UTC-04', '8. currency': 'USD', '9. matchScore': '1.0000'}]}
# {'bestMatches': [{'1. symbol': 'BCOW', '2. name': '1895 Bancorp of Wisconsin Inc.', '3. type': 'Equity', '4. region': 'United States', '5. marketOpen': '09:30', '6. marketClose': '16:00', '7. timezone': 'UTC-04', '8. currency': 'USD', '9. matchScore': '1.0000'}]}
# {'bestMatches': [{'1. symbol': 'FCCY', '2. name': '1st Constitution Bancorp', '3. type': 'Equity', '4. region': 'United States', '5. marketOpen': '09:30', '6. marketClose': '16:00', '7. timezone': 'UTC-04', '8. currency': 'USD', '9. matchScore': '1.0000'}]}
# {'bestMatches': [{'1. symbol': 'SRCE', '2. name': '1st Source Corporation', '3. type': 'Equity', '4. region': 'United States', '5. marketOpen': '09:30', '6. marketClose': '16:00', '7. timezone': 'UTC-04', '8. currency': 'USD', '9. matchScore': '1.0000'}]}
# {'bestMatches': [{'1. symbol': 'VNET', '2. name': '21Vianet Group Inc.', '3. type': 'Equity', '4. region': 'United States', '5. marketOpen': '09:30', '6. marketClose': '16:00', '7. timezone': 'UTC-04', '8. currency': 'USD', '9. matchScore': '1.0000'}, {'1. symbol': 'VNET.LON', '2. name': 'Vianet Group plc', '3. type': 'Equity', '4. region': 'United Kingdom', '5. marketOpen': '08:00', '6. marketClose': '16:30', '7. timezone': 'UTC+01', '8. currency': 'GBP', '9. matchScore': '0.8000'}]}
# {'Note': 'Thank you for using Alpha Vantage! Our standard API call frequency is 5 calls per minute and 500 calls per day. Please visit https://www.alphavantage.co/premium/ if you would like to target a higher API call frequency. Thank you!'}
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-63-a8a0b588f557> in <module>
#      52         dfFinal = df4.append(df5)
#      53     else:
# ---> 54         df6 = combine_csv_api (arraySymbols[x])
#      55         dfFinal = dfFinal.append(df6)
#      56 print (dfFinal)
#
# <ipython-input-63-a8a0b588f557> in combine_csv_api(symbol)
#      26         data = resp.json()
#      27         print (data)
# ---> 28         data = data['bestMatches']
#      29
#      30         df2 = pd.DataFrame.from_dict(data, orient='columns')
#
# KeyError: 'bestMatches'
